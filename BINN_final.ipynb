# %% [markdown]
# ### Imports

# %%
# Imports

# standard stuff
import pandas as pd
import numpy as np
from collections import Counter
import os
# Binn stuff
from binn import Network
from binn import BINN
from binn import BINNExplainer
# from the github of the binn
from util_for_examples import fit_data_matrix_to_network_input, generate_data
# our custom functions for training and testing
from cust_functions import training as trg
# torch stuff
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
# Sklearn stuff
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
SEED = 42
trg.set_seed(SEED)

# %% [markdown]
# ### Get Data

# %%
# Import covid data
covid_train = pd.read_csv('covid_data/covid_train_qm.csv', index_col=0)
covid_test = pd.read_csv('covid_data/covid_test_qm.csv', index_col=0)

covid_train_design = pd.read_csv('covid_data/covid_train_design_qm.csv', index_col=0)
covid_test_design = pd.read_csv('covid_data/covid_test_design_qm.csv', index_col=0)
covid_train_design["group"]+=1
covid_test_design["group"]+=1
translation = pd.read_csv("aki_data/translation.tsv", sep="\t", index_col=0)
pathways = pd.read_csv("aki_data/pathways.tsv", sep="\t")

# %%
#### Import aki data

# Get data, we have to tranform it first
input_data = pd.read_csv("aki_data/test_data.tsv", sep="\t", )
input_data_qm = pd.read_csv("aki_data/test_qm.csv")
translation = pd.read_csv("aki_data/translation.tsv", sep="\t", index_col=0)
pathways = pd.read_csv("aki_data/pathways.tsv", sep="\t")
design_matrix = pd.read_csv("aki_data/design_matrix.tsv", sep="\t")

# split into test and train according to paper
tm_p19_cols = [col for col in input_data_qm.columns if col.startswith("TM_P19")]
tm_m2012_cols = [col for col in input_data_qm.columns if col.startswith("TM_M2012")]

# Create train/test input based on these columns
test_input_data = input_data_qm[tm_p19_cols]
train_input_data = input_data_qm[tm_m2012_cols]
first_column = input_data_qm.iloc[:, 0]
train_input_data.insert(0, first_column.name, first_column)
test_input_data.insert(0, first_column.name, first_column)

#design_matrix
tm_m2012 = design_matrix['sample'].str.startswith("TM_M2012")
tm_p19 = design_matrix['sample'].str.startswith("TM_P19")
# Use the mask to create the separate DataFrames
test_design_matrix = design_matrix[tm_p19]
train_design_matrix = design_matrix[tm_m2012]

# %% [markdown]
# ### AKI
# - We perform 5-fold-CV

# %%
# 5 fold CV

# We first create an X tensor and a y tensor for the Corss validation. For this we create network/binn and make our x,y data so it fits the required input format
############# start of data creation ################
network = Network(
    input_data    =   train_input_data, 
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein", 
    source_column = "child", 
    target_column = "parent",
    subset_pathways = True
    )
binn = BINN(
        network=network,
        n_layers=4,
        dropout=0.2,
        validate=False,
        residual=False,
        device="cpu",
        learning_rate=0.001
    )

# Given functions to make the data network compatible
protein_matrix = fit_data_matrix_to_network_input(train_input_data, features=network.inputs)
X, y = generate_data(protein_matrix, design_matrix=train_design_matrix)
# Change to tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.int16)

################ end of data creation ################

# Place where we store the data
model_save_dir = "trained_models/AKI_BINN"
os.makedirs(model_save_dir, exist_ok=True)

# cross validation 5-times
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# we dont need more epochs 30 sufficient
num_epochs = 30
fold = 0
results = {}

for train_index, val_index in kf.split(X_tensor):
    fold += 1
    print(f"Starting fold {fold}")
    
    # Initialize a new network each fold
    network = Network(
    input_data    =   input_data_qm, # use the preprocessed data
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein", # This is the default value
    source_column = "child", # defined by our pathways-file
    target_column = "parent",
    subset_pathways = True # This is the default value
    )
    # Initate binn_aki for AKI
    binn_aki = BINN(
        network=network,
        n_layers=4,
        dropout=0.2,
        validate=False,
        residual=False,
        device="cpu",
        learning_rate=0.001
    )

    # train/ validation split
    X_train, X_val = X_tensor[train_index], X_tensor[val_index]
    y_train, y_val = y_tensor[train_index], y_tensor[val_index]
    # tensors
    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val) 
    # Load the data according to binn documentation
    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, drop_last=True)
    # get the opitmizer according to binn documentation
    optimizer = binn_aki.configure_optimizers()[0][0]
    
    # results dict
    results[fold] = {'train_loss': [], 'val_loss': [], 'train_accuracy': [], 'val_accuracy': [], "train_f1_macro":  [], "val_f1_macro":  [], "train_roc_auc": [], "val_roc_auc": [],
                     'train_f1_phen1': [], 'train_f1_phen2': [], 'train_recall_phen1': [], 'train_recall_phen2': [], 'train_precision_phen1': [], 'train_precision_phen2': [],
                     'val_f1_phen1': [], 'val_f1_phen2': [], 'val_recall_phen1': [], 'val_recall_phen2': [], 'val_precision_phen1': [], 'val_precision_phen2': [],"val_cm":[]
                     }
    # for best epoch needed later for plotting results
    best_val_loss = np.inf
    best_epoch = -1
    best_model_state = None
    # train the binn
    for epoch in range(num_epochs):
        # Training
        binn_aki.train()
        total_loss = 0.0
        total_accuracy = 0

        train_true_labels = []
        train_predictions = []

        val_true_labels = []  
        val_predictions = []

        for inputs, targets in train_loader:
            inputs = inputs.to(binn_aki.device)
            targets = targets.to(binn_aki.device).type(torch.LongTensor)
            optimizer.zero_grad()
            outputs = binn_aki(inputs)
            loss = F.cross_entropy(outputs, targets)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            total_accuracy += torch.sum(torch.argmax(outputs, axis=1) == targets) / len(targets)
            train_true_labels.append(targets.cpu().numpy())
            train_predictions.append(outputs.cpu().detach().numpy())  
        # get things for roc and cm
        train_true_labels = np.concatenate(train_true_labels)
        train_logits = np.concatenate(train_predictions, axis=0)
        train_probs = torch.softmax(torch.tensor(train_logits), dim=1).numpy()  # Assuming binary classification
        train_roc_auc = roc_auc_score(train_true_labels, train_probs[:, 1])
        train_pred_labels = np.argmax(train_probs, axis=1)
        
        # Get the metrics#########
        train_cm = confusion_matrix(train_true_labels, train_pred_labels)
        train_metrics = trg.calculate_metrics(train_cm)
        recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macro = train_metrics
        # loss and accuracy
        avg_loss = total_loss / len(train_loader)
        avg_accuracy = total_accuracy / len(train_loader)

        # add results
        results[fold]['train_loss'].append(avg_loss)
        results[fold]['train_accuracy'].append(accuracy.item())  # Ensure it's a scalar
        results[fold]['train_f1_macro'].append(f1_macro)
        results[fold]['train_roc_auc'].append(train_roc_auc)
        results[fold]['train_f1_phen1'].append(f1_phen1)
        results[fold]['train_f1_phen2'].append(f1_phen2)
        results[fold]['train_recall_phen1'].append(recall_phen1)
        results[fold]['train_recall_phen2'].append(recall_phen2)
        results[fold]['train_precision_phen1'].append(precision_phen1)
        results[fold]['train_precision_phen2'].append(precision_phen2)
        # Prints
        print(f'Epoch {epoch}, Training Average Accuracy {avg_accuracy}, Average Loss: {avg_loss}')

        #### start of  Validation ####
        binn_aki.eval()
        val_loss = 0.0
        val_accuracy = 0
        # evaluate
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs = inputs.to(binn_aki.device)
                targets = targets.to(binn_aki.device).type(torch.LongTensor)
                outputs = binn_aki(inputs)
                loss = F.cross_entropy(outputs, targets)
                val_loss += loss.item()
                val_accuracy += torch.sum(torch.argmax(outputs, axis=1) == targets) / len(targets)
                val_true_labels.append(targets.cpu().numpy())
                val_predictions.append(outputs.cpu().detach().numpy())  
        # roc and cm stuff and other metric stuff
        val_true_labels = np.concatenate(val_true_labels)
        val_logits = np.concatenate(val_predictions, axis=0)
        val_probs = torch.softmax(torch.tensor(val_logits), dim=1).numpy()  # Assuming binary classification
        val_roc_auc = roc_auc_score(val_true_labels, val_probs[:, 1])
        val_pred_labels = np.argmax(val_probs, axis=1)
        val_cm = confusion_matrix(val_true_labels, val_pred_labels)
        val_metrics = trg.calculate_metrics(val_cm) 
        recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macr = val_metrics       
        avg_val_loss = val_loss / len(val_loader)
        avg_val_accuracy = val_accuracy / len(val_loader)
        # prints
        print(f'Epoch {epoch}, Validation Average Accuracy {avg_val_accuracy}, Average Loss: {avg_val_loss}')
        
        # get results
        results[fold]['val_loss'].append(avg_val_loss)
        results[fold]['val_accuracy'].append(accuracy.item())  # Ensure it's a scalar
        results[fold]['val_f1_macro'].append(f1_macr)
        results[fold]['val_roc_auc'].append(val_roc_auc)
        results[fold]['val_f1_phen1'].append(f1_phen1)
        results[fold]['val_f1_phen2'].append(f1_phen2)
        results[fold]['val_recall_phen1'].append(recall_phen1)
        results[fold]['val_recall_phen2'].append(recall_phen2)
        results[fold]['val_precision_phen1'].append(precision_phen1)
        results[fold]['val_precision_phen2'].append(precision_phen2)
        results[fold]['val_cm'].append(val_cm)
        # best model stuff
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch
            best_model_state = binn_aki.state_dict().copy()

    if best_model_state is not None:
        model_save_path = os.path.join(model_save_dir, f"best_model_fold_{fold}.pth")
        torch.save(best_model_state, model_save_path)
    results[fold]['best_val_epoch'] = best_epoch
    # Safe the 5 models in the folder
    model_save_path = os.path.join(model_save_dir, f"model_fold_{fold}.pth")
    torch.save(binn_aki.state_dict(), model_save_path)

    print(f"Model saved for fold {fold} at {model_save_path}")
# Out:
# BINN is on the device: cpu
# dasdf
# Starting fold 1
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.5803571343421936, Average Loss: 0.7278988701956612
# Epoch 0, Validation Average Accuracy 0.4166666567325592, Average Loss: 0.6960683465003967
# Epoch 1, Training Average Accuracy 0.6964285969734192, Average Loss: 0.5690006986260414
# Epoch 1, Validation Average Accuracy 0.5416666865348816, Average Loss: 0.6890131632486979
# Epoch 2, Training Average Accuracy 0.7857142686843872, Average Loss: 0.5462133118084499
# Epoch 2, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.6278461416562399
# Epoch 3, Training Average Accuracy 0.8214285969734192, Average Loss: 0.4193757155111858
# Epoch 3, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.44102996587753296
# Epoch 4, Training Average Accuracy 0.7767857313156128, Average Loss: 0.4031062200665474
# Epoch 4, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.32784117261568707
# Epoch 5, Training Average Accuracy 0.8839285969734192, Average Loss: 0.30955864169767927
# Epoch 5, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.3200387607018153
# Epoch 6, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3328549212643078
# Epoch 6, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.28993382553259534
# Epoch 7, Training Average Accuracy 0.8392857313156128, Average Loss: 0.35935764759778976
# Epoch 7, Validation Average Accuracy 0.875, Average Loss: 0.2801182170708974
# Epoch 8, Training Average Accuracy 0.8214285969734192, Average Loss: 0.3769183893288885
# Epoch 8, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.2638467997312546
# Epoch 9, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3388970121741295
# Epoch 9, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.23276839902003607
# Epoch 10, Training Average Accuracy 0.9196428656578064, Average Loss: 0.24784805386194161
# Epoch 10, Validation Average Accuracy 1.0, Average Loss: 0.20216995974381766
# Epoch 11, Training Average Accuracy 0.9375, Average Loss: 0.22823393930281913
# Epoch 11, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.18571171661218008
# Epoch 12, Training Average Accuracy 0.9017857313156128, Average Loss: 0.30775923069034306
# Epoch 12, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.16445411493380865
# Epoch 13, Training Average Accuracy 0.9107142686843872, Average Loss: 0.2454659209719726
# Epoch 13, Validation Average Accuracy 1.0, Average Loss: 0.1532081812620163
# Epoch 14, Training Average Accuracy 0.8303571343421936, Average Loss: 0.33665927393095835
# Epoch 14, Validation Average Accuracy 1.0, Average Loss: 0.15063591301441193
# Epoch 15, Training Average Accuracy 0.9375, Average Loss: 0.212133437661188
# Epoch 15, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1516751324137052
# Epoch 16, Training Average Accuracy 0.9107142686843872, Average Loss: 0.2729527149349451
# Epoch 16, Validation Average Accuracy 1.0, Average Loss: 0.13654974599679312
# Epoch 17, Training Average Accuracy 0.9642857313156128, Average Loss: 0.1657483952918223
# Epoch 17, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1273780564467112
# Epoch 18, Training Average Accuracy 0.9821428656578064, Average Loss: 0.1622092808995928
# Epoch 18, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12372456987698872
# Epoch 19, Training Average Accuracy 0.8839285969734192, Average Loss: 0.2504138331860304
# Epoch 19, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12631537889440855
# Epoch 20, Training Average Accuracy 0.9196428656578064, Average Loss: 0.24723441606121405
# Epoch 20, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12167523552974065
# Epoch 21, Training Average Accuracy 0.9821428656578064, Average Loss: 0.13565040965165412
# Epoch 21, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10456624502937
# Epoch 22, Training Average Accuracy 0.9464285969734192, Average Loss: 0.16971223561891488
# Epoch 22, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12264979630708694
# Epoch 23, Training Average Accuracy 0.9642857313156128, Average Loss: 0.17947180170033658
# Epoch 23, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10911145557959874
# Epoch 24, Training Average Accuracy 0.8928571343421936, Average Loss: 0.22581708511071547
# Epoch 24, Validation Average Accuracy 1.0, Average Loss: 0.07659576088190079
# Epoch 25, Training Average Accuracy 0.9553571343421936, Average Loss: 0.12794018563415324
# Epoch 25, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.08333319673935573
# Epoch 26, Training Average Accuracy 0.9732142686843872, Average Loss: 0.13719758710690907
# Epoch 26, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.08503521978855133
# Epoch 27, Training Average Accuracy 0.9285714030265808, Average Loss: 0.20093896479478904
# Epoch 27, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1016237735748291
# Epoch 28, Training Average Accuracy 0.9375, Average Loss: 0.17906460565115725
# Epoch 28, Validation Average Accuracy 1.0, Average Loss: 0.07607393587629001
# Epoch 29, Training Average Accuracy 0.9375, Average Loss: 0.1904543566384486
# Epoch 29, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.07986023401220639
# Model saved for fold 1 at trained_models/AKI_BINN\model_fold_1.pth
# Starting fold 2
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.6339285969734192, Average Loss: 0.7436056328671319
# Epoch 0, Validation Average Accuracy 0.375, Average Loss: 0.7030807733535767
# Epoch 1, Training Average Accuracy 0.625, Average Loss: 0.6840786997761045
# Epoch 1, Validation Average Accuracy 0.375, Average Loss: 0.7100894451141357
# Epoch 2, Training Average Accuracy 0.6517857313156128, Average Loss: 0.6547144630125591
# Epoch 2, Validation Average Accuracy 0.375, Average Loss: 0.7098972400029501
# Epoch 3, Training Average Accuracy 0.6964285969734192, Average Loss: 0.5952127405575344
# Epoch 3, Validation Average Accuracy 0.6666666865348816, Average Loss: 0.6197164456049601
# Epoch 4, Training Average Accuracy 0.6517857313156128, Average Loss: 0.5719502312796456
# Epoch 4, Validation Average Accuracy 0.6666666865348816, Average Loss: 0.5799106856187185
# Epoch 5, Training Average Accuracy 0.7767857313156128, Average Loss: 0.48147438785859514
# Epoch 5, Validation Average Accuracy 0.7083333134651184, Average Loss: 0.6060090561707815
# Epoch 6, Training Average Accuracy 0.7946428656578064, Average Loss: 0.5032125466636249
# Epoch 6, Validation Average Accuracy 0.6666666865348816, Average Loss: 0.600833535194397
# Epoch 7, Training Average Accuracy 0.8035714030265808, Average Loss: 0.4401268703596933
# Epoch 7, Validation Average Accuracy 0.7916666865348816, Average Loss: 0.4962685803572337
# Epoch 8, Training Average Accuracy 0.7946428656578064, Average Loss: 0.41501855850219727
# Epoch 8, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.3853777050971985
# Epoch 9, Training Average Accuracy 0.8303571343421936, Average Loss: 0.36573317859854015
# Epoch 9, Validation Average Accuracy 0.7916666865348816, Average Loss: 0.36357925832271576
# Epoch 10, Training Average Accuracy 0.8035714030265808, Average Loss: 0.402316686298166
# Epoch 10, Validation Average Accuracy 0.875, Average Loss: 0.2856673573454221
# Epoch 11, Training Average Accuracy 0.8214285969734192, Average Loss: 0.38752806186676025
# Epoch 11, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.3541819006204605
# Epoch 12, Training Average Accuracy 0.8303571343421936, Average Loss: 0.4246905690857342
# Epoch 12, Validation Average Accuracy 0.7916666865348816, Average Loss: 0.34852374096711475
# Epoch 13, Training Average Accuracy 0.8392857313156128, Average Loss: 0.369713090892349
# Epoch 13, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.40616151442130405
# Epoch 14, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2950165170644011
# Epoch 14, Validation Average Accuracy 0.875, Average Loss: 0.2761111396054427
# Epoch 15, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3310006872883865
# Epoch 15, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.20547744631767273
# Epoch 16, Training Average Accuracy 0.8928571343421936, Average Loss: 0.3341292802776609
# Epoch 16, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.16272254784901938
# Epoch 17, Training Average Accuracy 0.9285714030265808, Average Loss: 0.22641754469701222
# Epoch 17, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.15705334022641182
# Epoch 18, Training Average Accuracy 0.9107142686843872, Average Loss: 0.2758747935295105
# Epoch 18, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.2035472939411799
# Epoch 19, Training Average Accuracy 0.9464285969734192, Average Loss: 0.22275746400867188
# Epoch 19, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.22050763045748076
# Epoch 20, Training Average Accuracy 0.9285714030265808, Average Loss: 0.2462297805718013
# Epoch 20, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.16820886979500452
# Epoch 21, Training Average Accuracy 0.9375, Average Loss: 0.19232345106346266
# Epoch 21, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.15052942807475725
# Epoch 22, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2624396216124296
# Epoch 22, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12295003980398178
# Epoch 23, Training Average Accuracy 0.9285714030265808, Average Loss: 0.20188346531774318
# Epoch 23, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.14473489920298258
# Epoch 24, Training Average Accuracy 0.8839285969734192, Average Loss: 0.24814094975590706
# Epoch 24, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1286124885082245
# Epoch 25, Training Average Accuracy 0.9375, Average Loss: 0.20645522778587683
# Epoch 25, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10479353989164035
# Epoch 26, Training Average Accuracy 0.9375, Average Loss: 0.21065006498247385
# Epoch 26, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.11251579597592354
# Epoch 27, Training Average Accuracy 0.9642857313156128, Average Loss: 0.13158384737159526
# Epoch 27, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10724494233727455
# Epoch 28, Training Average Accuracy 0.9285714030265808, Average Loss: 0.20978313365152904
# Epoch 28, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12768322291473547
# Epoch 29, Training Average Accuracy 0.9285714030265808, Average Loss: 0.2152540675763573
# Epoch 29, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10550887137651443
# Model saved for fold 2 at trained_models/AKI_BINN\model_fold_2.pth
# Starting fold 3
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.5357142686843872, Average Loss: 0.8441590539046696
# Epoch 0, Validation Average Accuracy 0.4583333432674408, Average Loss: 0.7031557957331339
# Epoch 1, Training Average Accuracy 0.6696428656578064, Average Loss: 0.5732892815555845
# Epoch 1, Validation Average Accuracy 0.4583333432674408, Average Loss: 0.7125107447306315
# Epoch 2, Training Average Accuracy 0.6696428656578064, Average Loss: 0.5959725571530206
# Epoch 2, Validation Average Accuracy 0.4583333432674408, Average Loss: 0.7045831481615702
# Epoch 3, Training Average Accuracy 0.7767857313156128, Average Loss: 0.5028432607650757
# Epoch 3, Validation Average Accuracy 0.6666666865348816, Average Loss: 0.5825233658154806
# Epoch 4, Training Average Accuracy 0.7857142686843872, Average Loss: 0.46811039107186453
# Epoch 4, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.438357671101888
# Epoch 5, Training Average Accuracy 0.7767857313156128, Average Loss: 0.4786442166992596
# Epoch 5, Validation Average Accuracy 0.875, Average Loss: 0.3210778037707011
# Epoch 6, Training Average Accuracy 0.8660714030265808, Average Loss: 0.3685602407370295
# Epoch 6, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.30278950929641724
# Epoch 7, Training Average Accuracy 0.8214285969734192, Average Loss: 0.3602541365793773
# Epoch 7, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.2670469929774602
# Epoch 8, Training Average Accuracy 0.8303571343421936, Average Loss: 0.40665905284030096
# Epoch 8, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.22986358652512232
# Epoch 9, Training Average Accuracy 0.8660714030265808, Average Loss: 0.31921030953526497
# Epoch 9, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.217288168768088
# Epoch 10, Training Average Accuracy 0.875, Average Loss: 0.29652792853968485
# Epoch 10, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.2167076493302981
# Epoch 11, Training Average Accuracy 0.8839285969734192, Average Loss: 0.27754696139267515
# Epoch 11, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.2018776759505272
# Epoch 12, Training Average Accuracy 0.8928571343421936, Average Loss: 0.28307514105524334
# Epoch 12, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.1648363620042801
# Epoch 13, Training Average Accuracy 0.8571428656578064, Average Loss: 0.28968364000320435
# Epoch 13, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.16228190685311952
# Epoch 14, Training Average Accuracy 0.8928571343421936, Average Loss: 0.28560233435460497
# Epoch 14, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.14804426953196526
# Epoch 15, Training Average Accuracy 0.875, Average Loss: 0.2684738566832883
# Epoch 15, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.14811402559280396
# Epoch 16, Training Average Accuracy 0.9017857313156128, Average Loss: 0.25687619351914953
# Epoch 16, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12327820683519046
# Epoch 17, Training Average Accuracy 0.9017857313156128, Average Loss: 0.29238341961588177
# Epoch 17, Validation Average Accuracy 1.0, Average Loss: 0.09743988886475563
# Epoch 18, Training Average Accuracy 0.9196428656578064, Average Loss: 0.22902657597192697
# Epoch 18, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10754063352942467
# Epoch 19, Training Average Accuracy 0.9107142686843872, Average Loss: 0.24016302398272923
# Epoch 19, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12862710654735565
# Epoch 20, Training Average Accuracy 0.875, Average Loss: 0.31608773342200686
# Epoch 20, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.14618160699804625
# Epoch 21, Training Average Accuracy 0.9285714030265808, Average Loss: 0.23008301055857114
# Epoch 21, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.12494859471917152
# Epoch 22, Training Average Accuracy 0.9464285969734192, Average Loss: 0.19152465888432094
# Epoch 22, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.09006899408996105
# Epoch 23, Training Average Accuracy 0.9464285969734192, Average Loss: 0.19127796164580754
# Epoch 23, Validation Average Accuracy 1.0, Average Loss: 0.07937633991241455
# Epoch 24, Training Average Accuracy 0.9107142686843872, Average Loss: 0.20710541095052445
# Epoch 24, Validation Average Accuracy 1.0, Average Loss: 0.07869291119277477
# Epoch 25, Training Average Accuracy 0.9553571343421936, Average Loss: 0.18905242399445601
# Epoch 25, Validation Average Accuracy 1.0, Average Loss: 0.08963203057646751
# Epoch 26, Training Average Accuracy 0.9375, Average Loss: 0.20891535920756205
# Epoch 26, Validation Average Accuracy 1.0, Average Loss: 0.0874017799894015
# Epoch 27, Training Average Accuracy 0.9375, Average Loss: 0.17853598216814653
# Epoch 27, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.11476945752898852
# Epoch 28, Training Average Accuracy 0.9553571343421936, Average Loss: 0.18523371831646987
# Epoch 28, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10687028865019481
# Epoch 29, Training Average Accuracy 0.9642857313156128, Average Loss: 0.15013471831168448
# Epoch 29, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10353789726893108
# Model saved for fold 3 at trained_models/AKI_BINN\model_fold_3.pth
# Starting fold 4
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.6339285969734192, Average Loss: 0.6514558174780437
# Epoch 0, Validation Average Accuracy 0.5416666865348816, Average Loss: 0.689428706963857
# Epoch 1, Training Average Accuracy 0.6517857313156128, Average Loss: 0.5912560565131051
# Epoch 1, Validation Average Accuracy 0.5416666865348816, Average Loss: 0.6850369373957316
# Epoch 2, Training Average Accuracy 0.7857142686843872, Average Loss: 0.4750108633722578
# Epoch 2, Validation Average Accuracy 0.5833333134651184, Average Loss: 0.6418283780415853
# Epoch 3, Training Average Accuracy 0.8214285969734192, Average Loss: 0.44927852707249777
# Epoch 3, Validation Average Accuracy 0.7916666865348816, Average Loss: 0.5058772365252177
# Epoch 4, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3695910615580423
# Epoch 4, Validation Average Accuracy 0.75, Average Loss: 0.42913663387298584
# Epoch 5, Training Average Accuracy 0.875, Average Loss: 0.40037837837423595
# Epoch 5, Validation Average Accuracy 0.875, Average Loss: 0.35813523332277936
# Epoch 6, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3656467582498278
# Epoch 6, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.3427000244458516
# Epoch 7, Training Average Accuracy 0.9017857313156128, Average Loss: 0.3108558676072529
# Epoch 7, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.36042559146881104
# Epoch 8, Training Average Accuracy 0.8928571343421936, Average Loss: 0.3172451928257942
# Epoch 8, Validation Average Accuracy 0.875, Average Loss: 0.30407293637593585
# Epoch 9, Training Average Accuracy 0.8660714030265808, Average Loss: 0.2813600280455181
# Epoch 9, Validation Average Accuracy 0.875, Average Loss: 0.23819003502527872
# Epoch 10, Training Average Accuracy 0.8839285969734192, Average Loss: 0.29542759167296545
# Epoch 10, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.24380833158890405
# Epoch 11, Training Average Accuracy 0.8839285969734192, Average Loss: 0.27014352700539995
# Epoch 11, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1978087897102038
# Epoch 12, Training Average Accuracy 0.9196428656578064, Average Loss: 0.2641209049948624
# Epoch 12, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.17720057566960654
# Epoch 13, Training Average Accuracy 0.9732142686843872, Average Loss: 0.1744156793824264
# Epoch 13, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.18072509268919626
# Epoch 14, Training Average Accuracy 0.9196428656578064, Average Loss: 0.2544640137680939
# Epoch 14, Validation Average Accuracy 0.875, Average Loss: 0.20968535542488098
# Epoch 15, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2329809388944081
# Epoch 15, Validation Average Accuracy 0.875, Average Loss: 0.3208489616711934
# Epoch 16, Training Average Accuracy 0.9642857313156128, Average Loss: 0.15597647481731006
# Epoch 16, Validation Average Accuracy 0.875, Average Loss: 0.32198749979337055
# Epoch 17, Training Average Accuracy 0.8928571343421936, Average Loss: 0.24756984625543868
# Epoch 17, Validation Average Accuracy 0.875, Average Loss: 0.22150885562102
# Epoch 18, Training Average Accuracy 0.9464285969734192, Average Loss: 0.19380101721201623
# Epoch 18, Validation Average Accuracy 0.875, Average Loss: 0.23993003368377686
# Epoch 19, Training Average Accuracy 0.9285714030265808, Average Loss: 0.1979581540716546
# Epoch 19, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.19766461352507272
# Epoch 20, Training Average Accuracy 0.8839285969734192, Average Loss: 0.274919190044914
# Epoch 20, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.2023464391628901
# Epoch 21, Training Average Accuracy 0.9107142686843872, Average Loss: 0.21205604821443558
# Epoch 21, Validation Average Accuracy 0.875, Average Loss: 0.18575382232666016
# Epoch 22, Training Average Accuracy 0.9017857313156128, Average Loss: 0.2439794402037348
# Epoch 22, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.24556084473927817
# Epoch 23, Training Average Accuracy 0.9553571343421936, Average Loss: 0.18831240545426095
# Epoch 23, Validation Average Accuracy 0.875, Average Loss: 0.17008390774329504
# Epoch 24, Training Average Accuracy 0.9107142686843872, Average Loss: 0.21831874868699483
# Epoch 24, Validation Average Accuracy 0.875, Average Loss: 0.1687521611650785
# Epoch 25, Training Average Accuracy 0.9553571343421936, Average Loss: 0.16446754442793982
# Epoch 25, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.13371407488981882
# Epoch 26, Training Average Accuracy 0.9642857313156128, Average Loss: 0.13968287488179548
# Epoch 26, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.14444121221701303
# Epoch 27, Training Average Accuracy 0.9642857313156128, Average Loss: 0.1936305905027049
# Epoch 27, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.14201457550128302
# Epoch 28, Training Average Accuracy 0.9642857313156128, Average Loss: 0.15842539178473608
# Epoch 28, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.13254728416601816
# Epoch 29, Training Average Accuracy 0.9375, Average Loss: 0.1645341951932226
# Epoch 29, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.11969191581010818
# Model saved for fold 4 at trained_models/AKI_BINN\model_fold_4.pth
# Starting fold 5
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.5625, Average Loss: 0.6999287690435138
# Epoch 0, Validation Average Accuracy 0.4583333432674408, Average Loss: 0.6948438684145609
# Epoch 1, Training Average Accuracy 0.6785714030265808, Average Loss: 0.6246539524623326
# Epoch 1, Validation Average Accuracy 0.7916666865348816, Average Loss: 0.686745802561442
# Epoch 2, Training Average Accuracy 0.625, Average Loss: 0.5883883259126118
# Epoch 2, Validation Average Accuracy 0.7916666865348816, Average Loss: 0.6306953827540079
# Epoch 3, Training Average Accuracy 0.8125, Average Loss: 0.4460128843784332
# Epoch 3, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.4508797029654185
# Epoch 4, Training Average Accuracy 0.7232142686843872, Average Loss: 0.461767594729151
# Epoch 4, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.3026868402957916
# Epoch 5, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3744080513715744
# Epoch 5, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.27321160584688187
# Epoch 6, Training Average Accuracy 0.8392857313156128, Average Loss: 0.33894786557980944
# Epoch 6, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.237116868297259
# Epoch 7, Training Average Accuracy 0.8571428656578064, Average Loss: 0.36581990654979435
# Epoch 7, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.18974238137404123
# Epoch 8, Training Average Accuracy 0.9285714030265808, Average Loss: 0.26667881863457815
# Epoch 8, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1647405525048574
# Epoch 9, Training Average Accuracy 0.9017857313156128, Average Loss: 0.3027883746794292
# Epoch 9, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.16511317094167074
# Epoch 10, Training Average Accuracy 0.875, Average Loss: 0.30609783636672155
# Epoch 10, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.18895475814739862
# Epoch 11, Training Average Accuracy 0.8660714030265808, Average Loss: 0.35290867941720144
# Epoch 11, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.15736156205336252
# Epoch 12, Training Average Accuracy 0.8839285969734192, Average Loss: 0.27288657799363136
# Epoch 12, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.13550486912329993
# Epoch 13, Training Average Accuracy 0.8928571343421936, Average Loss: 0.3040028448615755
# Epoch 13, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.1453293189406395
# Epoch 14, Training Average Accuracy 0.875, Average Loss: 0.27204410997884615
# Epoch 14, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.15412119155128798
# Epoch 15, Training Average Accuracy 0.9285714030265808, Average Loss: 0.24293668142386846
# Epoch 15, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12093104670445125
# Epoch 16, Training Average Accuracy 0.9107142686843872, Average Loss: 0.25311330067259924
# Epoch 16, Validation Average Accuracy 1.0, Average Loss: 0.09497503936290741
# Epoch 17, Training Average Accuracy 0.9285714030265808, Average Loss: 0.2277220684502806
# Epoch 17, Validation Average Accuracy 1.0, Average Loss: 0.09682634969552358
# Epoch 18, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2511196791061333
# Epoch 18, Validation Average Accuracy 1.0, Average Loss: 0.08884880691766739
# Epoch 19, Training Average Accuracy 0.9642857313156128, Average Loss: 0.16331752096968039
# Epoch 19, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.09492088481783867
# Epoch 20, Training Average Accuracy 0.9375, Average Loss: 0.23494087106415204
# Epoch 20, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10133474630614121
# Epoch 21, Training Average Accuracy 0.9107142686843872, Average Loss: 0.22684718322541034
# Epoch 21, Validation Average Accuracy 1.0, Average Loss: 0.09682937276860078
# Epoch 22, Training Average Accuracy 0.9285714030265808, Average Loss: 0.2223508907482028
# Epoch 22, Validation Average Accuracy 1.0, Average Loss: 0.08414334493378799
# Epoch 23, Training Average Accuracy 0.9196428656578064, Average Loss: 0.1691614022212369
# Epoch 23, Validation Average Accuracy 1.0, Average Loss: 0.06340366539855798
# Epoch 24, Training Average Accuracy 0.9196428656578064, Average Loss: 0.21077408308961562
# Epoch 24, Validation Average Accuracy 1.0, Average Loss: 0.07067139601955812
# Epoch 25, Training Average Accuracy 0.9107142686843872, Average Loss: 0.20665523170360497
# Epoch 25, Validation Average Accuracy 1.0, Average Loss: 0.06752945700039466
# Epoch 26, Training Average Accuracy 0.9017857313156128, Average Loss: 0.2341751434973308
# Epoch 26, Validation Average Accuracy 1.0, Average Loss: 0.07263930918027957
# Epoch 27, Training Average Accuracy 0.9464285969734192, Average Loss: 0.1665971345667328
# Epoch 27, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.10541728201011817
# Epoch 28, Training Average Accuracy 0.9553571343421936, Average Loss: 0.17250423984868185
# Epoch 28, Validation Average Accuracy 1.0, Average Loss: 0.06513241492211819
# Epoch 29, Training Average Accuracy 0.9375, Average Loss: 0.1731767033093742
# Epoch 29, Validation Average Accuracy 1.0, Average Loss: 0.050197954289615154
# Model saved for fold 5 at trained_models/AKI_BINN\model_fold_5.pth

# %% [markdown]
# ### Print metrics and scors

# %%
trg.print_val_results(results)
trg.plot_confusion_matrix(results)
trg.plot_results(results, 5)
# Out:
# Average validation accuracy: 0.975 +/- 0.02
# Average validation roc_auc: 0.999 +/- 0.0
# Average validation f1_macro: 0.974 +/- 0.02
# Average validation f1_phen1: 0.975 +/- 0.02
# Average validation f1_phen2: 0.974 +/- 0.02
# Average validation recall_phen1: 0.986 +/- 0.03
# Average validation recall_phen2: 0.968 +/- 0.04
# Average validation precision_phen1: 0.966 +/- 0.04
# Average validation precision_phen2: 0.982 +/- 0.04

# %% [markdown]
# ### Testing of the AKI data

# %%
# Test

num_folds = 5  
model_save_dir = "trained_models/AKI_BINN"  

# Load test data analogue to the train part
protein_matrix_test = fit_data_matrix_to_network_input(test_input_data, features=network.inputs)
X_test, y_test = generate_data(protein_matrix_test, design_matrix=test_design_matrix)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)  # tryout long instead of int16
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=8)  # Adjust batch size as needed

# get the predictions
all_predictions = []

# We go through each of the 5 cv models and get the predictions
for fold in range(1, num_folds + 1):
    model_path = f"{model_save_dir}/model_fold_{fold}.pth"
    model = binn_aki 
    model.load_state_dict(torch.load(model_path))
    model.eval()
    model.to(binn_aki.device)

    fold_predictions = []
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.to(binn_aki.device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            fold_predictions.extend(predicted.cpu().numpy())

    all_predictions.append(fold_predictions)


all_predictions = list(map(list, zip(*all_predictions)))
# majority voting
majority_votes = [Counter(sample_predictions).most_common(1)[0][0] for sample_predictions in all_predictions]

# accuracy
y_test = y_test_tensor.numpy()  # Convert to numpy if it's a tensor
correct = sum(1 for true, pred in zip(y_test, majority_votes) if true == pred)
accuracy = 100 * correct / len(y_test)

# cm, roc and other metrics
test_confusion_matrix = confusion_matrix(y_test, majority_votes, labels=[0, 1])

test_roc_auc = roc_auc_score(y_test, majority_votes)

recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macro = trg.calculate_metrics(test_confusion_matrix)



# Print metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test ROC_AUC: {test_roc_auc:.4f}")
print(f"Test F1 Macro: {f1_macro:.4f}")
print(f"Test F1 Phen1: {f1_phen1:.4f}")
print(f"Test F1 Phen2: {f1_phen2:.4f}")
print(f"Test Recall Phen1: {recall_phen1:.4f}")
print(f"Test Recall Phen2: {recall_phen2:.4f}")
trg.plot_confusion_matrix(test_confusion_matrix, use = 'test')
# Out:
# dasdf
# Test Accuracy: 0.8571
# Test ROC_AUC: 0.9000
# Test F1 Macro: 0.8444
# Test F1 Phen1: 0.8889
# Test F1 Phen2: 0.8000
# Test Recall Phen1: 0.8000
# Test Recall Phen2: 1.0000

# %% [markdown]
# ### Covid
# - we train 5-fold-cv
# - The code is the same as for the AKI only the data is different!!!!

# %%
### Training with k=5 CV
# Initiate network

# Same as in the AKI just different data
network = Network(
    input_data    =   covid_train, 
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein", 
    source_column = "child", 
    target_column = "parent",
    subset_pathways = True 
    )
binn = BINN(
    network=network,
    n_layers=4,
    dropout=0.2,
    validate=False,
    residual=False,
    device="cpu",
    learning_rate=0.001
)

protein_matrix = fit_data_matrix_to_network_input(covid_train, features=network.inputs)
X, y = generate_data(protein_matrix, design_matrix=covid_train_design)

X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.int16)

model_save_dir = "trained_models/Covid_BINN"
os.makedirs(model_save_dir, exist_ok=True)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

num_epochs = 30
fold = 0
results = {}

for train_index, val_index in kf.split(X_tensor):
    fold += 1
    print(f"Starting fold {fold}")
    
    network = Network(
    input_data    =   covid_train, 
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein",
    source_column = "child", 
    target_column = "parent",
    subset_pathways = True 
    )
    binn_covid = BINN(
        network=network,
        n_layers=4,
        dropout=0.2,
        validate=False,
        residual=False,
        device="cpu",
        learning_rate=0.001
    )

    X_train, X_val = X_tensor[train_index], X_tensor[val_index]
    y_train, y_val = y_tensor[train_index], y_tensor[val_index]

    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    

    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, drop_last=True)

    optimizer = binn_covid.configure_optimizers()[0][0]
    
    # results dict
    results[fold] = {'train_loss': [], 'val_loss': [], 'train_accuracy': [], 'val_accuracy': [], "train_f1_macro":  [], "val_f1_macro":  [], "train_roc_auc": [], "val_roc_auc": [],
                     'train_f1_phen1': [], 'train_f1_phen2': [], 'train_recall_phen1': [], 'train_recall_phen2': [], 'train_precision_phen1': [], 'train_precision_phen2': [],
                     'val_f1_phen1': [], 'val_f1_phen2': [], 'val_recall_phen1': [], 'val_recall_phen2': [], 'val_precision_phen1': [], 'val_precision_phen2': [],"val_cm":[]
                     }
    # for best epoch needed later for plotting results
    best_val_loss = np.inf
    best_epoch = -1
    best_model_state = None

    for epoch in range(num_epochs):
        # Training
        binn_covid.train()
        total_loss = 0.0
        total_accuracy = 0

        train_true_labels = []
        train_predictions = []

        val_true_labels = []
        val_predictions = []

        for inputs, targets in train_loader:
            inputs = inputs.to(binn_covid.device)
            targets = targets.to(binn_covid.device).type(torch.LongTensor)
            optimizer.zero_grad()
            outputs = binn_covid(inputs)
            loss = F.cross_entropy(outputs, targets)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            total_accuracy += torch.sum(torch.argmax(outputs, axis=1) == targets) / len(targets)

            train_true_labels.append(targets.cpu().numpy())
            train_predictions.append(outputs.cpu().detach().numpy())  

        train_true_labels = np.concatenate(train_true_labels)
        train_logits = np.concatenate(train_predictions, axis=0)
        train_probs = torch.softmax(torch.tensor(train_logits), dim=1).numpy()  # Assuming binary classification
        train_roc_auc = roc_auc_score(train_true_labels, train_probs[:, 1])
        
        train_pred_labels = np.argmax(train_probs, axis=1)
        

        # Get the metrics
        train_cm = confusion_matrix(train_true_labels, train_pred_labels)
        train_metrics = trg.calculate_metrics(train_cm)
        recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macro = train_metrics
        # loss and accuracy
        avg_loss = total_loss / len(train_loader)
        avg_accuracy = total_accuracy / len(train_loader)

        # add results
        results[fold]['train_loss'].append(avg_loss)
        results[fold]['train_accuracy'].append(accuracy.item())  # Ensure it's a scalar
        results[fold]['train_f1_macro'].append(f1_macro)
        results[fold]['train_roc_auc'].append(train_roc_auc)
        results[fold]['train_f1_phen1'].append(f1_phen1)
        results[fold]['train_f1_phen2'].append(f1_phen2)
        results[fold]['train_recall_phen1'].append(recall_phen1)
        results[fold]['train_recall_phen2'].append(recall_phen2)
        results[fold]['train_precision_phen1'].append(precision_phen1)
        results[fold]['train_precision_phen2'].append(precision_phen2)
        #############
        
        print(f'Epoch {epoch}, Training Average Accuracy {avg_accuracy}, Average Loss: {avg_loss}')

        # Validation
        binn_covid.eval()
        val_loss = 0.0
        val_accuracy = 0

        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs = inputs.to(binn_covid.device)
                targets = targets.to(binn_covid.device).type(torch.LongTensor)
                outputs = binn_covid(inputs)
                loss = F.cross_entropy(outputs, targets)
                val_loss += loss.item()
                val_accuracy += torch.sum(torch.argmax(outputs, axis=1) == targets) / len(targets)

                val_true_labels.append(targets.cpu().numpy())
                val_predictions.append(outputs.cpu().detach().numpy())  

        val_true_labels = np.concatenate(val_true_labels)
        val_logits = np.concatenate(val_predictions, axis=0)
        val_probs = torch.softmax(torch.tensor(val_logits), dim=1).numpy()  # Assuming binary classification
        val_roc_auc = roc_auc_score(val_true_labels, val_probs[:, 1])
        
        val_pred_labels = np.argmax(val_probs, axis=1)
        val_cm = confusion_matrix(val_true_labels, val_pred_labels)
        val_metrics = trg.calculate_metrics(val_cm) 
        recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macr = val_metrics       
        avg_val_loss = val_loss / len(val_loader)
        avg_val_accuracy = val_accuracy / len(val_loader)
        print(f'Epoch {epoch}, Validation Average Accuracy {avg_val_accuracy}, Average Loss: {avg_val_loss}')
        
        # validation
        results[fold]['val_loss'].append(avg_val_loss)
        results[fold]['val_accuracy'].append(accuracy.item())  # Ensure it's a scalar
        results[fold]['val_f1_macro'].append(f1_macr)
        results[fold]['val_roc_auc'].append(val_roc_auc)
        results[fold]['val_f1_phen1'].append(f1_phen1)
        results[fold]['val_f1_phen2'].append(f1_phen2)
        results[fold]['val_recall_phen1'].append(recall_phen1)
        results[fold]['val_recall_phen2'].append(recall_phen2)
        results[fold]['val_precision_phen1'].append(precision_phen1)
        results[fold]['val_precision_phen2'].append(precision_phen2)
        results[fold]['val_cm'].append(val_cm)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch
            best_model_state = binn_covid.state_dict().copy()

    if best_model_state is not None:
        model_save_path = os.path.join(model_save_dir, f"best_model_fold_{fold}.pth")
        torch.save(best_model_state, model_save_path)
    results[fold]['best_val_epoch'] = best_epoch
    # Safe the 5 models in the folder
    model_save_path = os.path.join(model_save_dir, f"model_fold_{fold}.pth")
    torch.save(binn_covid.state_dict(), model_save_path)

    print(f"Model saved for fold {fold} at {model_save_path}")
# Out:
# BINN is on the device: cpu
# dasdf
# Starting fold 1
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.6553571224212646, Average Loss: 0.6602986420903887
# Epoch 0, Validation Average Accuracy 0.7867646813392639, Average Loss: 0.45175076232236977
# Epoch 1, Training Average Accuracy 0.7285714149475098, Average Loss: 0.5616475895047188
# Epoch 1, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3728548419826171
# Epoch 2, Training Average Accuracy 0.7571428418159485, Average Loss: 0.5145997813769749
# Epoch 2, Validation Average Accuracy 0.845588207244873, Average Loss: 0.34902626977247353
# Epoch 3, Training Average Accuracy 0.7660714387893677, Average Loss: 0.4719536330018725
# Epoch 3, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.3457740019349491
# Epoch 4, Training Average Accuracy 0.7732142806053162, Average Loss: 0.45953258616583686
# Epoch 4, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3372410136987181
# Epoch 5, Training Average Accuracy 0.8017857074737549, Average Loss: 0.42290354796818325
# Epoch 5, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.3838456847211894
# Epoch 6, Training Average Accuracy 0.7607142925262451, Average Loss: 0.47328991357769284
# Epoch 6, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3283233430017443
# Epoch 7, Training Average Accuracy 0.8125, Average Loss: 0.4320222117006779
# Epoch 7, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.31646108145222945
# Epoch 8, Training Average Accuracy 0.7946428656578064, Average Loss: 0.43950617739132475
# Epoch 8, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.34252820667975087
# Epoch 9, Training Average Accuracy 0.7946428656578064, Average Loss: 0.4013372720352241
# Epoch 9, Validation Average Accuracy 0.845588207244873, Average Loss: 0.29922787231557507
# Epoch 10, Training Average Accuracy 0.8053571581840515, Average Loss: 0.4340685527239527
# Epoch 10, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.30115454424830046
# Epoch 11, Training Average Accuracy 0.8160714507102966, Average Loss: 0.4012103550136089
# Epoch 11, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.29124366360552173
# Epoch 12, Training Average Accuracy 0.8214285969734192, Average Loss: 0.3855765885540417
# Epoch 12, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2728455704362953
# Epoch 13, Training Average Accuracy 0.8410714268684387, Average Loss: 0.34968808165618354
# Epoch 13, Validation Average Accuracy 0.875, Average Loss: 0.27887101493337574
# Epoch 14, Training Average Accuracy 0.8464285731315613, Average Loss: 0.3617848058896405
# Epoch 14, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2706695500323001
# Epoch 15, Training Average Accuracy 0.8160714507102966, Average Loss: 0.4247656176132815
# Epoch 15, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.2997753606999622
# Epoch 16, Training Average Accuracy 0.8517857193946838, Average Loss: 0.34947187315140454
# Epoch 16, Validation Average Accuracy 0.875, Average Loss: 0.2792621995596325
# Epoch 17, Training Average Accuracy 0.8607142567634583, Average Loss: 0.33224078826606274
# Epoch 17, Validation Average Accuracy 0.875, Average Loss: 0.27791285624398904
# Epoch 18, Training Average Accuracy 0.8553571701049805, Average Loss: 0.3694855143449136
# Epoch 18, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.27232229008394127
# Epoch 19, Training Average Accuracy 0.8017857074737549, Average Loss: 0.4447873214525836
# Epoch 19, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.28119877944974336
# Epoch 20, Training Average Accuracy 0.8410714268684387, Average Loss: 0.391925610601902
# Epoch 20, Validation Average Accuracy 0.875, Average Loss: 0.2832615002989769
# Epoch 21, Training Average Accuracy 0.8446428775787354, Average Loss: 0.35006479088749204
# Epoch 21, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.29824660050080104
# Epoch 22, Training Average Accuracy 0.8446428775787354, Average Loss: 0.3614080120410238
# Epoch 22, Validation Average Accuracy 0.875, Average Loss: 0.2736602554864743
# Epoch 23, Training Average Accuracy 0.8392857313156128, Average Loss: 0.36629125167216575
# Epoch 23, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.2791853638037163
# Epoch 24, Training Average Accuracy 0.8410714268684387, Average Loss: 0.35595485301954405
# Epoch 24, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.281344259815181
# Epoch 25, Training Average Accuracy 0.8267857432365417, Average Loss: 0.3877231506364686
# Epoch 25, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3109599001267377
# Epoch 26, Training Average Accuracy 0.8339285850524902, Average Loss: 0.3893411633159433
# Epoch 26, Validation Average Accuracy 0.875, Average Loss: 0.31099119935842123
# Epoch 27, Training Average Accuracy 0.8803571462631226, Average Loss: 0.32026245892047883
# Epoch 27, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.31392334993271265
# Epoch 28, Training Average Accuracy 0.8232142925262451, Average Loss: 0.371720154689891
# Epoch 28, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.27979807500891823
# Epoch 29, Training Average Accuracy 0.8500000238418579, Average Loss: 0.35375291172947204
# Epoch 29, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.287020551150336
# Model saved for fold 1 at trained_models/Covid_BINN\model_fold_1.pth
# Starting fold 2
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.5910714268684387, Average Loss: 0.7519628835575921
# Epoch 0, Validation Average Accuracy 0.720588207244873, Average Loss: 0.5279616336612141
# Epoch 1, Training Average Accuracy 0.7142857313156128, Average Loss: 0.558361439193998
# Epoch 1, Validation Average Accuracy 0.779411792755127, Average Loss: 0.49567558134303374
# Epoch 2, Training Average Accuracy 0.7214285731315613, Average Loss: 0.5393672770687512
# Epoch 2, Validation Average Accuracy 0.7941176295280457, Average Loss: 0.49932288641438766
# Epoch 3, Training Average Accuracy 0.7589285969734192, Average Loss: 0.4970942283315318
# Epoch 3, Validation Average Accuracy 0.8161764740943909, Average Loss: 0.43646253382458405
# Epoch 4, Training Average Accuracy 0.8017857074737549, Average Loss: 0.44467922534261434
# Epoch 4, Validation Average Accuracy 0.8235294222831726, Average Loss: 0.4437805852469276
# Epoch 5, Training Average Accuracy 0.8017857074737549, Average Loss: 0.455090908067567
# Epoch 5, Validation Average Accuracy 0.8161764740943909, Average Loss: 0.40467002987861633
# Epoch 6, Training Average Accuracy 0.8089285492897034, Average Loss: 0.41977028719016485
# Epoch 6, Validation Average Accuracy 0.8308823704719543, Average Loss: 0.39616017920129437
# Epoch 7, Training Average Accuracy 0.8214285969734192, Average Loss: 0.386826163317476
# Epoch 7, Validation Average Accuracy 0.8235294222831726, Average Loss: 0.397114621804041
# Epoch 8, Training Average Accuracy 0.7803571224212646, Average Loss: 0.4497821449169091
# Epoch 8, Validation Average Accuracy 0.8235294222831726, Average Loss: 0.39466775471673293
# Epoch 9, Training Average Accuracy 0.8303571343421936, Average Loss: 0.36028855400426046
# Epoch 9, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.37827758008942886
# Epoch 10, Training Average Accuracy 0.7803571224212646, Average Loss: 0.4671954099621092
# Epoch 10, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.4010758277247934
# Epoch 11, Training Average Accuracy 0.8071428537368774, Average Loss: 0.4327889974628176
# Epoch 11, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.38514545537969647
# Epoch 12, Training Average Accuracy 0.8392857313156128, Average Loss: 0.3775408482977322
# Epoch 12, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3877941479577738
# Epoch 13, Training Average Accuracy 0.8446428775787354, Average Loss: 0.36205803251692226
# Epoch 13, Validation Average Accuracy 0.845588207244873, Average Loss: 0.36552517335204515
# Epoch 14, Training Average Accuracy 0.8392857313156128, Average Loss: 0.3754192150064877
# Epoch 14, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.3645976424655494
# Epoch 15, Training Average Accuracy 0.8321428298950195, Average Loss: 0.3711394590990884
# Epoch 15, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.359260429354275
# Epoch 16, Training Average Accuracy 0.8321428298950195, Average Loss: 0.38641040069716315
# Epoch 16, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.3378703206339303
# Epoch 17, Training Average Accuracy 0.8178571462631226, Average Loss: 0.38989116208893915
# Epoch 17, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.3385033809086856
# Epoch 18, Training Average Accuracy 0.8357142806053162, Average Loss: 0.38038068796907154
# Epoch 18, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.36005975744303537
# Epoch 19, Training Average Accuracy 0.8357142806053162, Average Loss: 0.3601735797311578
# Epoch 19, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.3443365787320277
# Epoch 20, Training Average Accuracy 0.8553571701049805, Average Loss: 0.3465912954083511
# Epoch 20, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.3480031712747672
# Epoch 21, Training Average Accuracy 0.8464285731315613, Average Loss: 0.3667381552713258
# Epoch 21, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.3283705299391466
# Epoch 22, Training Average Accuracy 0.824999988079071, Average Loss: 0.35987977337624344
# Epoch 22, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.358446329832077
# Epoch 23, Training Average Accuracy 0.8464285731315613, Average Loss: 0.36849885902234486
# Epoch 23, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.37262659541824283
# Epoch 24, Training Average Accuracy 0.8464285731315613, Average Loss: 0.3622362671153886
# Epoch 24, Validation Average Accuracy 0.875, Average Loss: 0.35706925260670047
# Epoch 25, Training Average Accuracy 0.8607142567634583, Average Loss: 0.32991718596645764
# Epoch 25, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.3392884341232917
# Epoch 26, Training Average Accuracy 0.8446428775787354, Average Loss: 0.36688655550990784
# Epoch 26, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.3489275287617655
# Epoch 27, Training Average Accuracy 0.8535714149475098, Average Loss: 0.33289551362395287
# Epoch 27, Validation Average Accuracy 0.875, Average Loss: 0.35940367421683145
# Epoch 28, Training Average Accuracy 0.8339285850524902, Average Loss: 0.3663518496922084
# Epoch 28, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.3591361352626015
# Epoch 29, Training Average Accuracy 0.8428571224212646, Average Loss: 0.3589643509260246
# Epoch 29, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.36521361571024447
# Model saved for fold 2 at trained_models/Covid_BINN\model_fold_2.pth
# Starting fold 3
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.574999988079071, Average Loss: 0.7464635316814695
# Epoch 0, Validation Average Accuracy 0.6470588445663452, Average Loss: 0.5685231387615204
# Epoch 1, Training Average Accuracy 0.7285714149475098, Average Loss: 0.5594747981854847
# Epoch 1, Validation Average Accuracy 0.7647058963775635, Average Loss: 0.4934563792365439
# Epoch 2, Training Average Accuracy 0.7821428775787354, Average Loss: 0.4815209788935525
# Epoch 2, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.39516444767222686
# Epoch 3, Training Average Accuracy 0.7749999761581421, Average Loss: 0.4554928643362863
# Epoch 3, Validation Average Accuracy 0.875, Average Loss: 0.3050362684709184
# Epoch 4, Training Average Accuracy 0.8017857074737549, Average Loss: 0.44892022247825353
# Epoch 4, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.3038292886579738
# Epoch 5, Training Average Accuracy 0.7839285731315613, Average Loss: 0.45831054928047316
# Epoch 5, Validation Average Accuracy 0.845588207244873, Average Loss: 0.30991876607432084
# Epoch 6, Training Average Accuracy 0.7964285612106323, Average Loss: 0.4389536393540246
# Epoch 6, Validation Average Accuracy 0.875, Average Loss: 0.28870246296419816
# Epoch 7, Training Average Accuracy 0.8107143044471741, Average Loss: 0.4100559326154845
# Epoch 7, Validation Average Accuracy 0.875, Average Loss: 0.29353039470665593
# Epoch 8, Training Average Accuracy 0.7928571701049805, Average Loss: 0.43157666751316615
# Epoch 8, Validation Average Accuracy 0.904411792755127, Average Loss: 0.2680999978500254
# Epoch 9, Training Average Accuracy 0.8160714507102966, Average Loss: 0.41717117897101813
# Epoch 9, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2617519912036026
# Epoch 10, Training Average Accuracy 0.8053571581840515, Average Loss: 0.4015994841498988
# Epoch 10, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2691551486358923
# Epoch 11, Training Average Accuracy 0.8285714387893677, Average Loss: 0.38180754259228705
# Epoch 11, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.27398116601740613
# Epoch 12, Training Average Accuracy 0.8089285492897034, Average Loss: 0.41835745764630183
# Epoch 12, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.279648437657777
# Epoch 13, Training Average Accuracy 0.8214285969734192, Average Loss: 0.3823406898549625
# Epoch 13, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.2963287136791384
# Epoch 14, Training Average Accuracy 0.8374999761581421, Average Loss: 0.3716823386294501
# Epoch 14, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3032179049709264
# Epoch 15, Training Average Accuracy 0.8482142686843872, Average Loss: 0.382561576792172
# Epoch 15, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.28949185942902284
# Epoch 16, Training Average Accuracy 0.8071428537368774, Average Loss: 0.42319572823388235
# Epoch 16, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.28162962198257446
# Epoch 17, Training Average Accuracy 0.8178571462631226, Average Loss: 0.41435211960758483
# Epoch 17, Validation Average Accuracy 0.845588207244873, Average Loss: 0.30733729964670015
# Epoch 18, Training Average Accuracy 0.8339285850524902, Average Loss: 0.36673577800393103
# Epoch 18, Validation Average Accuracy 0.845588207244873, Average Loss: 0.2921455888187184
# Epoch 19, Training Average Accuracy 0.8160714507102966, Average Loss: 0.39508368873170446
# Epoch 19, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.2702527383671087
# Epoch 20, Training Average Accuracy 0.8500000238418579, Average Loss: 0.34434868757213866
# Epoch 20, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.28017571568489075
# Epoch 21, Training Average Accuracy 0.8303571343421936, Average Loss: 0.3735126064292022
# Epoch 21, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.28900522563387365
# Epoch 22, Training Average Accuracy 0.824999988079071, Average Loss: 0.3938723406621388
# Epoch 22, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.2955034581177375
# Epoch 23, Training Average Accuracy 0.8660714030265808, Average Loss: 0.3708831200642245
# Epoch 23, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.29070507296744513
# Epoch 24, Training Average Accuracy 0.8303571343421936, Average Loss: 0.373221797815391
# Epoch 24, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.27588751561501446
# Epoch 25, Training Average Accuracy 0.8214285969734192, Average Loss: 0.3812439944062914
# Epoch 25, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2751562021234456
# Epoch 26, Training Average Accuracy 0.8589285612106323, Average Loss: 0.3259141819817679
# Epoch 26, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2564438388628118
# Epoch 27, Training Average Accuracy 0.8303571343421936, Average Loss: 0.38798701422555104
# Epoch 27, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2807397088583778
# Epoch 28, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3437384642660618
# Epoch 28, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2689028283690705
# Epoch 29, Training Average Accuracy 0.8410714268684387, Average Loss: 0.35622610375285146
# Epoch 29, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.2648555794182946
# Model saved for fold 3 at trained_models/Covid_BINN\model_fold_3.pth
# Starting fold 4
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.6625000238418579, Average Loss: 0.6925425865820476
# Epoch 0, Validation Average Accuracy 0.720588207244873, Average Loss: 0.5364009816856945
# Epoch 1, Training Average Accuracy 0.6928571462631226, Average Loss: 0.6047070020011494
# Epoch 1, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.3672332838177681
# Epoch 2, Training Average Accuracy 0.7285714149475098, Average Loss: 0.5405878774821758
# Epoch 2, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3212733593057184
# Epoch 3, Training Average Accuracy 0.7892857193946838, Average Loss: 0.47082126459905077
# Epoch 3, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.30817195247201357
# Epoch 4, Training Average Accuracy 0.7839285731315613, Average Loss: 0.47350606694817543
# Epoch 4, Validation Average Accuracy 0.875, Average Loss: 0.32306572312817855
# Epoch 5, Training Average Accuracy 0.7732142806053162, Average Loss: 0.4687999551849706
# Epoch 5, Validation Average Accuracy 0.875, Average Loss: 0.27116531703402014
# Epoch 6, Training Average Accuracy 0.7910714149475098, Average Loss: 0.46256803125143053
# Epoch 6, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.27477316558361053
# Epoch 7, Training Average Accuracy 0.8017857074737549, Average Loss: 0.43452890227947916
# Epoch 7, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.24391164104728139
# Epoch 8, Training Average Accuracy 0.7982142567634583, Average Loss: 0.4579341609563146
# Epoch 8, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2669154265347649
# Epoch 9, Training Average Accuracy 0.7946428656578064, Average Loss: 0.457482166162559
# Epoch 9, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.24090512820026455
# Epoch 10, Training Average Accuracy 0.800000011920929, Average Loss: 0.4394869886338711
# Epoch 10, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2908752602251137
# Epoch 11, Training Average Accuracy 0.8303571343421936, Average Loss: 0.4095370837620326
# Epoch 11, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.22871125949656262
# Epoch 12, Training Average Accuracy 0.8285714387893677, Average Loss: 0.3814386499779565
# Epoch 12, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.22606704844271436
# Epoch 13, Training Average Accuracy 0.8321428298950195, Average Loss: 0.40073830240539143
# Epoch 13, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.24430799637647235
# Epoch 14, Training Average Accuracy 0.8267857432365417, Average Loss: 0.38873272304024015
# Epoch 14, Validation Average Accuracy 0.9117646813392639, Average Loss: 0.25040771768373604
# Epoch 15, Training Average Accuracy 0.8285714387893677, Average Loss: 0.39430929603321213
# Epoch 15, Validation Average Accuracy 0.904411792755127, Average Loss: 0.2217588044483872
# Epoch 16, Training Average Accuracy 0.8214285969734192, Average Loss: 0.4065106621810368
# Epoch 16, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2366450415814624
# Epoch 17, Training Average Accuracy 0.8196428418159485, Average Loss: 0.3706204957727875
# Epoch 17, Validation Average Accuracy 0.9264705777168274, Average Loss: 0.2360629049294135
# Epoch 18, Training Average Accuracy 0.8410714268684387, Average Loss: 0.3657546762909208
# Epoch 18, Validation Average Accuracy 0.9117646813392639, Average Loss: 0.21536634402240024
# Epoch 19, Training Average Accuracy 0.8142856955528259, Average Loss: 0.40059492087789944
# Epoch 19, Validation Average Accuracy 0.9117646813392639, Average Loss: 0.2232676757609143
# Epoch 20, Training Average Accuracy 0.8392857313156128, Average Loss: 0.39242128846900803
# Epoch 20, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2548035922295907
# Epoch 21, Training Average Accuracy 0.8214285969734192, Average Loss: 0.38902504050305914
# Epoch 21, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2491834027802243
# Epoch 22, Training Average Accuracy 0.8285714387893677, Average Loss: 0.4020936462496008
# Epoch 22, Validation Average Accuracy 0.904411792755127, Average Loss: 0.24706819653511047
# Epoch 23, Training Average Accuracy 0.8392857313156128, Average Loss: 0.3776056363114289
# Epoch 23, Validation Average Accuracy 0.875, Average Loss: 0.2700658629045767
# Epoch 24, Training Average Accuracy 0.8392857313156128, Average Loss: 0.38207847912396703
# Epoch 24, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.29043878790210276
# Epoch 25, Training Average Accuracy 0.8285714387893677, Average Loss: 0.3896856268601758
# Epoch 25, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.266722209751606
# Epoch 26, Training Average Accuracy 0.8500000238418579, Average Loss: 0.36903997702257973
# Epoch 26, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2540777588591856
# Epoch 27, Training Average Accuracy 0.8446428775787354, Average Loss: 0.3710367755166122
# Epoch 27, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2865287455565789
# Epoch 28, Training Average Accuracy 0.8357142806053162, Average Loss: 0.3607655770012311
# Epoch 28, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.25904159554663825
# Epoch 29, Training Average Accuracy 0.8482142686843872, Average Loss: 0.34654660943363397
# Epoch 29, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.24185199312427463
# Model saved for fold 4 at trained_models/Covid_BINN\model_fold_4.pth
# Starting fold 5
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.6142857074737549, Average Loss: 0.6843579692499978
# Epoch 0, Validation Average Accuracy 0.779411792755127, Average Loss: 0.4446767647476757
# Epoch 1, Training Average Accuracy 0.7714285850524902, Average Loss: 0.5119221836328507
# Epoch 1, Validation Average Accuracy 0.7867646813392639, Average Loss: 0.45982501129893694
# Epoch 2, Training Average Accuracy 0.8035714030265808, Average Loss: 0.4614907648946558
# Epoch 2, Validation Average Accuracy 0.8235294222831726, Average Loss: 0.3978033924804014
# Epoch 3, Training Average Accuracy 0.8017857074737549, Average Loss: 0.4464380641068731
# Epoch 3, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.3827565351829809
# Epoch 4, Training Average Accuracy 0.800000011920929, Average Loss: 0.4514116898179054
# Epoch 4, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.36032892982749376
# Epoch 5, Training Average Accuracy 0.8125, Average Loss: 0.4368489875325135
# Epoch 5, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3552723469979623
# Epoch 6, Training Average Accuracy 0.7732142806053162, Average Loss: 0.4600168208990778
# Epoch 6, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3610372039325097
# Epoch 7, Training Average Accuracy 0.7946428656578064, Average Loss: 0.4460139004247529
# Epoch 7, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.35098204498781876
# Epoch 8, Training Average Accuracy 0.8071428537368774, Average Loss: 0.425289202694382
# Epoch 8, Validation Average Accuracy 0.845588207244873, Average Loss: 0.34127408835817785
# Epoch 9, Training Average Accuracy 0.8232142925262451, Average Loss: 0.4013864154262202
# Epoch 9, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3514251441640012
# Epoch 10, Training Average Accuracy 0.8357142806053162, Average Loss: 0.3661002724298409
# Epoch 10, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.33781582555350137
# Epoch 11, Training Average Accuracy 0.8285714387893677, Average Loss: 0.38689949810504914
# Epoch 11, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.3610137630911434
# Epoch 12, Training Average Accuracy 0.8160714507102966, Average Loss: 0.39055979571172167
# Epoch 12, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3897985347053584
# Epoch 13, Training Average Accuracy 0.8357142806053162, Average Loss: 0.3858909832579749
# Epoch 13, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3956475266638924
# Epoch 14, Training Average Accuracy 0.8285714387893677, Average Loss: 0.3885564675288541
# Epoch 14, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.37171994018204074
# Epoch 15, Training Average Accuracy 0.8321428298950195, Average Loss: 0.40771127502833093
# Epoch 15, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.33665448514854207
# Epoch 16, Training Average Accuracy 0.8232142925262451, Average Loss: 0.3959841723952975
# Epoch 16, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3826778550796649
# Epoch 17, Training Average Accuracy 0.824999988079071, Average Loss: 0.39515249973961286
# Epoch 17, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3079653088660801
# Epoch 18, Training Average Accuracy 0.824999988079071, Average Loss: 0.4011787323015077
# Epoch 18, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.31208666194887724
# Epoch 19, Training Average Accuracy 0.8392857313156128, Average Loss: 0.37578686720558574
# Epoch 19, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.32217952740543027
# Epoch 20, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3651008790092809
# Epoch 20, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.31745099276304245
# Epoch 21, Training Average Accuracy 0.8553571701049805, Average Loss: 0.3578601762652397
# Epoch 21, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.31165915639961467
# Epoch 22, Training Average Accuracy 0.8357142806053162, Average Loss: 0.40635844224265644
# Epoch 22, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3234950369771789
# Epoch 23, Training Average Accuracy 0.8589285612106323, Average Loss: 0.3502846501767635
# Epoch 23, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3578311248737223
# Epoch 24, Training Average Accuracy 0.8303571343421936, Average Loss: 0.3814377024769783
# Epoch 24, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3263630060588612
# Epoch 25, Training Average Accuracy 0.8446428775787354, Average Loss: 0.33913481384515765
# Epoch 25, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.31815818039809957
# Epoch 26, Training Average Accuracy 0.8660714030265808, Average Loss: 0.3360757840531213
# Epoch 26, Validation Average Accuracy 0.845588207244873, Average Loss: 0.32819149796577063
# Epoch 27, Training Average Accuracy 0.8607142567634583, Average Loss: 0.34688291592257364
# Epoch 27, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3220761896056287
# Epoch 28, Training Average Accuracy 0.8125, Average Loss: 0.40804475050951755
# Epoch 28, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.32098907188457604
# Epoch 29, Training Average Accuracy 0.8553571701049805, Average Loss: 0.33833642224115984
# Epoch 29, Validation Average Accuracy 0.875, Average Loss: 0.3119203481165802
# Model saved for fold 5 at trained_models/Covid_BINN\model_fold_5.pth

# %%
trg.print_val_results(results)
trg.plot_confusion_matrix(results)
trg.plot_results(results, 5)
# Out:
# Average validation accuracy: 0.882 +/- 0.03
# Average validation roc_auc: 0.948 +/- 0.01
# Average validation f1_macro: 0.88 +/- 0.03
# Average validation f1_phen1: 0.891 +/- 0.03
# Average validation f1_phen2: 0.87 +/- 0.03
# Average validation recall_phen1: 0.914 +/- 0.03
# Average validation recall_phen2: 0.851 +/- 0.08
# Average validation precision_phen1: 0.873 +/- 0.06
# Average validation precision_phen2: 0.898 +/- 0.03

# %% [markdown]
# ### Test Covid data

# %%
num_folds = 5  
model_save_dir = "trained_models/Covid_BINN" 

# Load test data
protein_matrix_test = fit_data_matrix_to_network_input(covid_test, features=network.inputs)
X_test, y_test = generate_data(protein_matrix_test, design_matrix=covid_test_design)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long) 
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=8)  

all_predictions = []

# go through each of the 5 models
for fold in range(1, num_folds + 1):
    model_path = f"{model_save_dir}/model_fold_{fold}.pth"
    model = binn_covid 
    model.load_state_dict(torch.load(model_path))
    model.eval()
    model.to(binn_covid.device)  

    fold_predictions = []
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.to(binn_covid.device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            fold_predictions.extend(predicted.cpu().numpy())

    all_predictions.append(fold_predictions)

all_predictions = list(map(list, zip(*all_predictions)))
majority_votes = [Counter(sample_predictions).most_common(1)[0][0] for sample_predictions in all_predictions]

# Calculate accuracy
y_test = y_test_tensor.numpy()  # Convert to numpy if it's a tensor
correct = sum(1 for true, pred in zip(y_test, majority_votes) if true == pred)
accuracy = 100 * correct / len(y_test)


test_confusion_matrix = confusion_matrix(y_test, majority_votes, labels=[0, 1])

test_roc_auc = roc_auc_score(y_test, majority_votes)

recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macro = trg.calculate_metrics(test_confusion_matrix)



# Print metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test ROC_AUC: {test_roc_auc:.4f}")
print(f"Test F1 Macro: {f1_macro:.4f}")
print(f"Test F1 Phen1: {f1_phen1:.4f}")
print(f"Test F1 Phen2: {f1_phen2:.4f}")
print(f"Test Recall Phen1: {recall_phen1:.4f}")
print(f"Test Recall Phen2: {recall_phen2:.4f}")
trg.plot_confusion_matrix(test_confusion_matrix, use = 'test')
# Out:
# dasdf
# Test Accuracy: 0.8354
# Test ROC_AUC: 0.8338
# Test F1 Macro: 0.8345
# Test F1 Phen1: 0.8471
# Test F1 Phen2: 0.8219
# Test Recall Phen1: 0.8780
# Test Recall Phen2: 0.7895
