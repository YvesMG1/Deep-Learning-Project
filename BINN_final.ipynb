# %% [markdown]
# ### Imports

# %%
# Imports

# standard stuff
import pandas as pd
import numpy as np
from collections import Counter
import os
# Binn stuff
from binn import Network
from binn import BINN
from binn import BINNExplainer
# from the github of the binn
from util_for_examples import fit_data_matrix_to_network_input, generate_data
# our custom functions for training and testing
from cust_functions import training as trg
# torch stuff
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
# Sklearn stuff
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ### Get Data

# %%
# Import covid data
covid_train = pd.read_csv('covid_data/covid_train_qm.csv', index_col=0)
covid_test = pd.read_csv('covid_data/covid_test_qm.csv', index_col=0)

covid_train_design = pd.read_csv('covid_data/covid_train_design_qm.csv', index_col=0)
covid_test_design = pd.read_csv('covid_data/covid_test_design_qm.csv', index_col=0)
covid_train_design["group"]+=1
covid_test_design["group"]+=1
translation = pd.read_csv("aki_data/translation.tsv", sep="\t", index_col=0)
pathways = pd.read_csv("aki_data/pathways.tsv", sep="\t")

# %%
#### Import aki data

# Get data, we have to tranform it first
input_data = pd.read_csv("aki_data/test_data.tsv", sep="\t", )
input_data_qm = pd.read_csv("aki_data/test_qm.csv")
translation = pd.read_csv("aki_data/translation.tsv", sep="\t", index_col=0)
pathways = pd.read_csv("aki_data/pathways.tsv", sep="\t")
design_matrix = pd.read_csv("aki_data/design_matrix.tsv", sep="\t")

# split into test and train according to paper
tm_p19_cols = [col for col in input_data_qm.columns if col.startswith("TM_P19")]
tm_m2012_cols = [col for col in input_data_qm.columns if col.startswith("TM_M2012")]

# Create train/test input based on these columns
test_input_data = input_data_qm[tm_p19_cols]
train_input_data = input_data_qm[tm_m2012_cols]
first_column = input_data_qm.iloc[:, 0]
train_input_data.insert(0, first_column.name, first_column)
test_input_data.insert(0, first_column.name, first_column)

#design_matrix
tm_m2012 = design_matrix['sample'].str.startswith("TM_M2012")
tm_p19 = design_matrix['sample'].str.startswith("TM_P19")
# Use the mask to create the separate DataFrames
test_design_matrix = design_matrix[tm_p19]
train_design_matrix = design_matrix[tm_m2012]

# %% [markdown]
# ### AKI
# - We perform 5-fold-CV

# %%
# 5 fold CV

# We first create an X tensor and a y tensor for the Corss validation. For this we create network/binn and make our x,y data so it fits the required input format
############# start of data creation ################
network = Network(
    input_data    =   train_input_data, 
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein", 
    source_column = "child", 
    target_column = "parent",
    subset_pathways = True
    )
binn = BINN(
        network=network,
        n_layers=4,
        dropout=0.2,
        validate=False,
        residual=False,
        device="cpu",
        learning_rate=0.001
    )

# Given functions to make the data network compatible
protein_matrix = fit_data_matrix_to_network_input(train_input_data, features=network.inputs)
X, y = generate_data(protein_matrix, design_matrix=train_design_matrix)
# Change to tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.int16)

################ end of data creation ################

# Place where we store the data
model_save_dir = "trained_models/AKI_BINN"
os.makedirs(model_save_dir, exist_ok=True)

# cross validation 5-times
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# we dont need more epochs 30 sufficient
num_epochs = 30
fold = 0
results = {}

for train_index, val_index in kf.split(X_tensor):
    fold += 1
    print(f"Starting fold {fold}")
    
    # Initialize a new network each fold
    network = Network(
    input_data    =   input_data_qm, # use the preprocessed data
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein", # This is the default value
    source_column = "child", # defined by our pathways-file
    target_column = "parent",
    subset_pathways = True # This is the default value
    )
    # Initate binn_aki for AKI
    binn_aki = BINN(
        network=network,
        n_layers=4,
        dropout=0.2,
        validate=False,
        residual=False,
        device="cpu",
        learning_rate=0.001
    )

    # train/ validation split
    X_train, X_val = X_tensor[train_index], X_tensor[val_index]
    y_train, y_val = y_tensor[train_index], y_tensor[val_index]
    # tensors
    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val) 
    # Load the data according to binn documentation
    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, drop_last=True)
    # get the opitmizer according to binn documentation
    optimizer = binn_aki.configure_optimizers()[0][0]
    
    # results dict
    results[fold] = {'train_loss': [], 'val_loss': [], 'train_accuracy': [], 'val_accuracy': [], "train_f1_macro":  [], "val_f1_macro":  [], "train_roc_auc": [], "val_roc_auc": [],
                     'train_f1_phen1': [], 'train_f1_phen2': [], 'train_recall_phen1': [], 'train_recall_phen2': [], 'train_precision_phen1': [], 'train_precision_phen2': [],
                     'val_f1_phen1': [], 'val_f1_phen2': [], 'val_recall_phen1': [], 'val_recall_phen2': [], 'val_precision_phen1': [], 'val_precision_phen2': [],"val_cm":[]
                     }
    # for best epoch needed later for plotting results
    best_val_loss = np.inf
    best_epoch = -1
    best_model_state = None
    # train the binn
    for epoch in range(num_epochs):
        # Training
        binn_aki.train()
        total_loss = 0.0
        total_accuracy = 0

        train_true_labels = []
        train_predictions = []

        val_true_labels = []  
        val_predictions = []

        for inputs, targets in train_loader:
            inputs = inputs.to(binn_aki.device)
            targets = targets.to(binn_aki.device).type(torch.LongTensor)
            optimizer.zero_grad()
            outputs = binn_aki(inputs)
            loss = F.cross_entropy(outputs, targets)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            total_accuracy += torch.sum(torch.argmax(outputs, axis=1) == targets) / len(targets)
            train_true_labels.append(targets.cpu().numpy())
            train_predictions.append(outputs.cpu().detach().numpy())  
        # get things for roc and cm
        train_true_labels = np.concatenate(train_true_labels)
        train_logits = np.concatenate(train_predictions, axis=0)
        train_probs = torch.softmax(torch.tensor(train_logits), dim=1).numpy()  # Assuming binary classification
        train_roc_auc = roc_auc_score(train_true_labels, train_probs[:, 1])
        train_pred_labels = np.argmax(train_probs, axis=1)
        
        # Get the metrics#########
        train_cm = confusion_matrix(train_true_labels, train_pred_labels)
        train_metrics = trg.calculate_metrics(train_cm)
        recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macro = train_metrics
        # loss and accuracy
        avg_loss = total_loss / len(train_loader)
        avg_accuracy = total_accuracy / len(train_loader)

        # add results
        results[fold]['train_loss'].append(avg_loss)
        results[fold]['train_accuracy'].append(accuracy.item())  # Ensure it's a scalar
        results[fold]['train_f1_macro'].append(f1_macro)
        results[fold]['train_roc_auc'].append(train_roc_auc)
        results[fold]['train_f1_phen1'].append(f1_phen1)
        results[fold]['train_f1_phen2'].append(f1_phen2)
        results[fold]['train_recall_phen1'].append(recall_phen1)
        results[fold]['train_recall_phen2'].append(recall_phen2)
        results[fold]['train_precision_phen1'].append(precision_phen1)
        results[fold]['train_precision_phen2'].append(precision_phen2)
        # Prints
        print(f'Epoch {epoch}, Training Average Accuracy {avg_accuracy}, Average Loss: {avg_loss}')

        #### start of  Validation ####
        binn_aki.eval()
        val_loss = 0.0
        val_accuracy = 0
        # evaluate
        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs = inputs.to(binn_aki.device)
                targets = targets.to(binn_aki.device).type(torch.LongTensor)
                outputs = binn_aki(inputs)
                loss = F.cross_entropy(outputs, targets)
                val_loss += loss.item()
                val_accuracy += torch.sum(torch.argmax(outputs, axis=1) == targets) / len(targets)
                val_true_labels.append(targets.cpu().numpy())
                val_predictions.append(outputs.cpu().detach().numpy())  
        # roc and cm stuff and other metric stuff
        val_true_labels = np.concatenate(val_true_labels)
        val_logits = np.concatenate(val_predictions, axis=0)
        val_probs = torch.softmax(torch.tensor(val_logits), dim=1).numpy()  # Assuming binary classification
        val_roc_auc = roc_auc_score(val_true_labels, val_probs[:, 1])
        val_pred_labels = np.argmax(val_probs, axis=1)
        val_cm = confusion_matrix(val_true_labels, val_pred_labels)
        val_metrics = trg.calculate_metrics(val_cm) 
        recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macr = val_metrics       
        avg_val_loss = val_loss / len(val_loader)
        avg_val_accuracy = val_accuracy / len(val_loader)
        # prints
        print(f'Epoch {epoch}, Validation Average Accuracy {avg_val_accuracy}, Average Loss: {avg_val_loss}')
        
        # get results
        results[fold]['val_loss'].append(avg_val_loss)
        results[fold]['val_accuracy'].append(accuracy.item())  # Ensure it's a scalar
        results[fold]['val_f1_macro'].append(f1_macr)
        results[fold]['val_roc_auc'].append(val_roc_auc)
        results[fold]['val_f1_phen1'].append(f1_phen1)
        results[fold]['val_f1_phen2'].append(f1_phen2)
        results[fold]['val_recall_phen1'].append(recall_phen1)
        results[fold]['val_recall_phen2'].append(recall_phen2)
        results[fold]['val_precision_phen1'].append(precision_phen1)
        results[fold]['val_precision_phen2'].append(precision_phen2)
        results[fold]['val_cm'].append(val_cm)
        # best model stuff
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch
            best_model_state = binn_aki.state_dict().copy()

    if best_model_state is not None:
        model_save_path = os.path.join(model_save_dir, f"best_model_fold_{fold}.pth")
        torch.save(best_model_state, model_save_path)
    results[fold]['best_val_epoch'] = best_epoch
    # Safe the 5 models in the folder
    model_save_path = os.path.join(model_save_dir, f"model_fold_{fold}.pth")
    torch.save(binn_aki.state_dict(), model_save_path)

    print(f"Model saved for fold {fold} at {model_save_path}")
# Out:
# BINN is on the device: cpu
# dasdf
# Starting fold 1
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.625, Average Loss: 0.6710938683577946
# Epoch 0, Validation Average Accuracy 0.5833333134651184, Average Loss: 0.688206136226654
# Epoch 1, Training Average Accuracy 0.6696428656578064, Average Loss: 0.5965936545814786
# Epoch 1, Validation Average Accuracy 0.5833333134651184, Average Loss: 0.6838879187901815
# Epoch 2, Training Average Accuracy 0.7053571343421936, Average Loss: 0.5402929357119969
# Epoch 2, Validation Average Accuracy 0.5416666865348816, Average Loss: 0.6541733543078104
# Epoch 3, Training Average Accuracy 0.75, Average Loss: 0.5115800627640316
# Epoch 3, Validation Average Accuracy 0.7083333134651184, Average Loss: 0.5229528347651163
# Epoch 4, Training Average Accuracy 0.8392857313156128, Average Loss: 0.36102742914642605
# Epoch 4, Validation Average Accuracy 0.7916666865348816, Average Loss: 0.4361938287814458
# Epoch 5, Training Average Accuracy 0.9107142686843872, Average Loss: 0.29357430764607023
# Epoch 5, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.3751261532306671
# Epoch 6, Training Average Accuracy 0.8928571343421936, Average Loss: 0.3045041954943112
# Epoch 6, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.36167161911726
# Epoch 7, Training Average Accuracy 0.875, Average Loss: 0.3078996943575995
# Epoch 7, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.27844105164210003
# Epoch 8, Training Average Accuracy 0.8214285969734192, Average Loss: 0.35097751553569523
# Epoch 8, Validation Average Accuracy 0.875, Average Loss: 0.24294748157262802
# Epoch 9, Training Average Accuracy 0.8660714030265808, Average Loss: 0.30132547872407095
# Epoch 9, Validation Average Accuracy 0.875, Average Loss: 0.25287165741125744
# Epoch 10, Training Average Accuracy 0.9196428656578064, Average Loss: 0.26797732764056753
# Epoch 10, Validation Average Accuracy 0.875, Average Loss: 0.1992515871922175
# Epoch 11, Training Average Accuracy 0.875, Average Loss: 0.27865046156304224
# Epoch 11, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.21072597056627274
# Epoch 12, Training Average Accuracy 0.9017857313156128, Average Loss: 0.2700917912381036
# Epoch 12, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.2056074341138204
# Epoch 13, Training Average Accuracy 0.8928571343421936, Average Loss: 0.3070906437933445
# Epoch 13, Validation Average Accuracy 0.875, Average Loss: 0.20920231690009436
# Epoch 14, Training Average Accuracy 0.8839285969734192, Average Loss: 0.29367408262831823
# Epoch 14, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.2519732465346654
# Epoch 15, Training Average Accuracy 0.875, Average Loss: 0.2708922140300274
# Epoch 15, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.19766933719317117
# Epoch 16, Training Average Accuracy 0.9107142686843872, Average Loss: 0.24404671415686607
# Epoch 16, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.172929418583711
# Epoch 17, Training Average Accuracy 0.8839285969734192, Average Loss: 0.2759514669222491
# Epoch 17, Validation Average Accuracy 1.0, Average Loss: 0.15465956926345825
# Epoch 18, Training Average Accuracy 0.875, Average Loss: 0.2885136290320328
# Epoch 18, Validation Average Accuracy 1.0, Average Loss: 0.14532276491324106
# Epoch 19, Training Average Accuracy 0.9107142686843872, Average Loss: 0.19615575245448522
# Epoch 19, Validation Average Accuracy 1.0, Average Loss: 0.1181841529905796
# Epoch 20, Training Average Accuracy 0.9107142686843872, Average Loss: 0.22555962098496302
# Epoch 20, Validation Average Accuracy 1.0, Average Loss: 0.11728960524002711
# Epoch 21, Training Average Accuracy 0.9107142686843872, Average Loss: 0.23964560936604226
# Epoch 21, Validation Average Accuracy 1.0, Average Loss: 0.10288021961847942
# Epoch 22, Training Average Accuracy 0.9196428656578064, Average Loss: 0.23929210432938167
# Epoch 22, Validation Average Accuracy 1.0, Average Loss: 0.09300969789425532
# Epoch 23, Training Average Accuracy 0.9017857313156128, Average Loss: 0.2473656636263643
# Epoch 23, Validation Average Accuracy 1.0, Average Loss: 0.11099376281102498
# Epoch 24, Training Average Accuracy 0.9285714030265808, Average Loss: 0.22249783069959708
# Epoch 24, Validation Average Accuracy 1.0, Average Loss: 0.09692877282698949
# Epoch 25, Training Average Accuracy 0.9821428656578064, Average Loss: 0.14081198083502905
# Epoch 25, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.13539407278100649
# Epoch 26, Training Average Accuracy 0.9375, Average Loss: 0.20741832788501466
# Epoch 26, Validation Average Accuracy 1.0, Average Loss: 0.08615229030450185
# Epoch 27, Training Average Accuracy 0.9017857313156128, Average Loss: 0.24717036421809876
# Epoch 27, Validation Average Accuracy 1.0, Average Loss: 0.06689654663205147
# Epoch 28, Training Average Accuracy 0.9107142686843872, Average Loss: 0.24634640956563608
# Epoch 28, Validation Average Accuracy 1.0, Average Loss: 0.06176051373283068
# Epoch 29, Training Average Accuracy 1.0, Average Loss: 0.1034300843519824
# Epoch 29, Validation Average Accuracy 1.0, Average Loss: 0.05880612755815188
# Model saved for fold 1 at trained_models/AKI_BINN\model_fold_1.pth
# Starting fold 2
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.4910714328289032, Average Loss: 0.9199810368674142
# Epoch 0, Validation Average Accuracy 0.625, Average Loss: 0.680498480796814
# Epoch 1, Training Average Accuracy 0.6875, Average Loss: 0.6378137235130582
# Epoch 1, Validation Average Accuracy 0.625, Average Loss: 0.6855708758036295
# Epoch 2, Training Average Accuracy 0.6875, Average Loss: 0.6213739109890801
# Epoch 2, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.6531042456626892
# Epoch 3, Training Average Accuracy 0.7321428656578064, Average Loss: 0.5726924794060844
# Epoch 3, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.47983665267626446
# Epoch 4, Training Average Accuracy 0.7678571343421936, Average Loss: 0.45474701268332346
# Epoch 4, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.3322563370068868
# Epoch 5, Training Average Accuracy 0.8125, Average Loss: 0.4728857310754912
# Epoch 5, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.21764626105626425
# Epoch 6, Training Average Accuracy 0.8214285969734192, Average Loss: 0.4337879568338394
# Epoch 6, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.18376488983631134
# Epoch 7, Training Average Accuracy 0.8125, Average Loss: 0.39810615299003466
# Epoch 7, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.16647564868132272
# Epoch 8, Training Average Accuracy 0.8035714030265808, Average Loss: 0.4158409833908081
# Epoch 8, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1330639993151029
# Epoch 9, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3253153072936194
# Epoch 9, Validation Average Accuracy 1.0, Average Loss: 0.12601919223864874
# Epoch 10, Training Average Accuracy 0.8571428656578064, Average Loss: 0.27753175316112383
# Epoch 10, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12704799820979437
# Epoch 11, Training Average Accuracy 0.8839285969734192, Average Loss: 0.2781985434038298
# Epoch 11, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12521801640590033
# Epoch 12, Training Average Accuracy 0.8482142686843872, Average Loss: 0.40783560276031494
# Epoch 12, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.13363677263259888
# Epoch 13, Training Average Accuracy 0.875, Average Loss: 0.3040207102894783
# Epoch 13, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12001046972970168
# Epoch 14, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2837633064814976
# Epoch 14, Validation Average Accuracy 1.0, Average Loss: 0.08654019236564636
# Epoch 15, Training Average Accuracy 0.8571428656578064, Average Loss: 0.33826372187052456
# Epoch 15, Validation Average Accuracy 1.0, Average Loss: 0.08206632360816002
# Epoch 16, Training Average Accuracy 0.8214285969734192, Average Loss: 0.35903415083885193
# Epoch 16, Validation Average Accuracy 1.0, Average Loss: 0.07661706457535426
# Epoch 17, Training Average Accuracy 0.9196428656578064, Average Loss: 0.20394226536154747
# Epoch 17, Validation Average Accuracy 1.0, Average Loss: 0.07428142800927162
# Epoch 18, Training Average Accuracy 0.9017857313156128, Average Loss: 0.25942645967006683
# Epoch 18, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1023167942961057
# Epoch 19, Training Average Accuracy 0.9017857313156128, Average Loss: 0.2476487811654806
# Epoch 19, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.11019100435078144
# Epoch 20, Training Average Accuracy 0.9732142686843872, Average Loss: 0.19321655003087862
# Epoch 20, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.11159345445533593
# Epoch 21, Training Average Accuracy 0.9017857313156128, Average Loss: 0.20864752201097353
# Epoch 21, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.10614188698430856
# Epoch 22, Training Average Accuracy 0.9107142686843872, Average Loss: 0.2226026342915637
# Epoch 22, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.08519660557309787
# Epoch 23, Training Average Accuracy 0.9196428656578064, Average Loss: 0.1924610622227192
# Epoch 23, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.07333064824342728
# Epoch 24, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2040358686021396
# Epoch 24, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.07681484955052535
# Epoch 25, Training Average Accuracy 0.8839285969734192, Average Loss: 0.25471184296267374
# Epoch 25, Validation Average Accuracy 1.0, Average Loss: 0.046665050710241
# Epoch 26, Training Average Accuracy 0.9196428656578064, Average Loss: 0.1969292089343071
# Epoch 26, Validation Average Accuracy 1.0, Average Loss: 0.055924677600463234
# Epoch 27, Training Average Accuracy 0.9017857313156128, Average Loss: 0.28464257770351004
# Epoch 27, Validation Average Accuracy 1.0, Average Loss: 0.03900120034813881
# Epoch 28, Training Average Accuracy 0.9017857313156128, Average Loss: 0.18710111693612166
# Epoch 28, Validation Average Accuracy 1.0, Average Loss: 0.03559245727956295
# Epoch 29, Training Average Accuracy 0.8928571343421936, Average Loss: 0.1963355698223625
# Epoch 29, Validation Average Accuracy 1.0, Average Loss: 0.057136001996695995
# Model saved for fold 2 at trained_models/AKI_BINN\model_fold_2.pth
# Starting fold 3
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.5357142686843872, Average Loss: 0.7850586239780698
# Epoch 0, Validation Average Accuracy 0.4583333432674408, Average Loss: 0.7046448588371277
# Epoch 1, Training Average Accuracy 0.6964285969734192, Average Loss: 0.5896467289754322
# Epoch 1, Validation Average Accuracy 0.4583333432674408, Average Loss: 0.7089705864588419
# Epoch 2, Training Average Accuracy 0.6607142686843872, Average Loss: 0.6618207139628274
# Epoch 2, Validation Average Accuracy 0.5, Average Loss: 0.669567863146464
# Epoch 3, Training Average Accuracy 0.75, Average Loss: 0.5231065813984189
# Epoch 3, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.5158625145753225
# Epoch 4, Training Average Accuracy 0.7946428656578064, Average Loss: 0.45889244973659515
# Epoch 4, Validation Average Accuracy 0.875, Average Loss: 0.37874817848205566
# Epoch 5, Training Average Accuracy 0.8571428656578064, Average Loss: 0.420832348721368
# Epoch 5, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.3276258210341136
# Epoch 6, Training Average Accuracy 0.8125, Average Loss: 0.4672178104519844
# Epoch 6, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.2891765534877777
# Epoch 7, Training Average Accuracy 0.8035714030265808, Average Loss: 0.4100900601063456
# Epoch 7, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.2617354393005371
# Epoch 8, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3332284784742764
# Epoch 8, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.225524440407753
# Epoch 9, Training Average Accuracy 0.8214285969734192, Average Loss: 0.37923875557524817
# Epoch 9, Validation Average Accuracy 0.875, Average Loss: 0.2247426025569439
# Epoch 10, Training Average Accuracy 0.8660714030265808, Average Loss: 0.34765248213495525
# Epoch 10, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.21626809115211168
# Epoch 11, Training Average Accuracy 0.8928571343421936, Average Loss: 0.3175432596887861
# Epoch 11, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.20556963980197906
# Epoch 12, Training Average Accuracy 0.8928571343421936, Average Loss: 0.3089186091508184
# Epoch 12, Validation Average Accuracy 1.0, Average Loss: 0.17534912005066872
# Epoch 13, Training Average Accuracy 0.8839285969734192, Average Loss: 0.31487334413187845
# Epoch 13, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.14299319932858148
# Epoch 14, Training Average Accuracy 0.8839285969734192, Average Loss: 0.31999855062791277
# Epoch 14, Validation Average Accuracy 1.0, Average Loss: 0.12856350963314375
# Epoch 15, Training Average Accuracy 0.8839285969734192, Average Loss: 0.3096777908504009
# Epoch 15, Validation Average Accuracy 1.0, Average Loss: 0.1326781635483106
# Epoch 16, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3096971224461283
# Epoch 16, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.13593397662043571
# Epoch 17, Training Average Accuracy 0.9107142686843872, Average Loss: 0.26020650033439907
# Epoch 17, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12653207033872604
# Epoch 18, Training Average Accuracy 0.9285714030265808, Average Loss: 0.23416308739355632
# Epoch 18, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.14792542035380998
# Epoch 19, Training Average Accuracy 0.8839285969734192, Average Loss: 0.30512960095490727
# Epoch 19, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.14533129893243313
# Epoch 20, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2735362452055727
# Epoch 20, Validation Average Accuracy 1.0, Average Loss: 0.1190696507692337
# Epoch 21, Training Average Accuracy 0.9107142686843872, Average Loss: 0.24031006864139012
# Epoch 21, Validation Average Accuracy 1.0, Average Loss: 0.10492542944848537
# Epoch 22, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2562271361904485
# Epoch 22, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12510201086600622
# Epoch 23, Training Average Accuracy 0.9375, Average Loss: 0.21548036858439445
# Epoch 23, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12893849735458693
# Epoch 24, Training Average Accuracy 0.9910714030265808, Average Loss: 0.1382756605744362
# Epoch 24, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12512177973985672
# Epoch 25, Training Average Accuracy 0.9196428656578064, Average Loss: 0.24563305984650338
# Epoch 25, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.09911461360752583
# Epoch 26, Training Average Accuracy 0.9285714030265808, Average Loss: 0.22200357115694455
# Epoch 26, Validation Average Accuracy 1.0, Average Loss: 0.07690005128582318
# Epoch 27, Training Average Accuracy 0.9375, Average Loss: 0.19297644389527185
# Epoch 27, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.08194582350552082
# Epoch 28, Training Average Accuracy 0.9375, Average Loss: 0.15188840962946415
# Epoch 28, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.08152239955961704
# Epoch 29, Training Average Accuracy 0.9017857313156128, Average Loss: 0.24573220472250665
# Epoch 29, Validation Average Accuracy 1.0, Average Loss: 0.0673498905574282
# Model saved for fold 3 at trained_models/AKI_BINN\model_fold_3.pth
# Starting fold 4
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.5267857313156128, Average Loss: 0.8500763263021197
# Epoch 0, Validation Average Accuracy 0.4583333432674408, Average Loss: 0.7037534117698669
# Epoch 1, Training Average Accuracy 0.6607142686843872, Average Loss: 0.6122808967317853
# Epoch 1, Validation Average Accuracy 0.4583333432674408, Average Loss: 0.6994817058245341
# Epoch 2, Training Average Accuracy 0.6517857313156128, Average Loss: 0.6287453302315303
# Epoch 2, Validation Average Accuracy 0.75, Average Loss: 0.6644370158513387
# Epoch 3, Training Average Accuracy 0.7232142686843872, Average Loss: 0.5205291264823505
# Epoch 3, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.5491302808125814
# Epoch 4, Training Average Accuracy 0.7232142686843872, Average Loss: 0.523768058844975
# Epoch 4, Validation Average Accuracy 0.8333333134651184, Average Loss: 0.41763219237327576
# Epoch 5, Training Average Accuracy 0.7857142686843872, Average Loss: 0.46052840671369005
# Epoch 5, Validation Average Accuracy 0.875, Average Loss: 0.35408206780751544
# Epoch 6, Training Average Accuracy 0.7767857313156128, Average Loss: 0.43523970246315
# Epoch 6, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.29180870453516644
# Epoch 7, Training Average Accuracy 0.7857142686843872, Average Loss: 0.43155416526964735
# Epoch 7, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.3000214745601018
# Epoch 8, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3995944006102426
# Epoch 8, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.2734062870343526
# Epoch 9, Training Average Accuracy 0.8928571343421936, Average Loss: 0.2732780171292169
# Epoch 9, Validation Average Accuracy 0.875, Average Loss: 0.24201990912357965
# Epoch 10, Training Average Accuracy 0.8839285969734192, Average Loss: 0.3228390152965273
# Epoch 10, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.20599370698134103
# Epoch 11, Training Average Accuracy 0.8482142686843872, Average Loss: 0.38692051651222364
# Epoch 11, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.18599944561719894
# Epoch 12, Training Average Accuracy 0.875, Average Loss: 0.27917865025145666
# Epoch 12, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.17035685231288275
# Epoch 13, Training Average Accuracy 0.8660714030265808, Average Loss: 0.31358594819903374
# Epoch 13, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.16243308782577515
# Epoch 14, Training Average Accuracy 0.9107142686843872, Average Loss: 0.2797154667122023
# Epoch 14, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.17239616314570108
# Epoch 15, Training Average Accuracy 0.8928571343421936, Average Loss: 0.25400292554071974
# Epoch 15, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.1696729784210523
# Epoch 16, Training Average Accuracy 0.875, Average Loss: 0.2853152299565928
# Epoch 16, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.15089777981241545
# Epoch 17, Training Average Accuracy 0.9375, Average Loss: 0.21793857323271887
# Epoch 17, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.13605237503846487
# Epoch 18, Training Average Accuracy 0.9732142686843872, Average Loss: 0.16401107715708868
# Epoch 18, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.11943530788024266
# Epoch 19, Training Average Accuracy 0.9017857313156128, Average Loss: 0.24572075477668218
# Epoch 19, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.11948217948277791
# Epoch 20, Training Average Accuracy 0.9017857313156128, Average Loss: 0.2462419867515564
# Epoch 20, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.124736654261748
# Epoch 21, Training Average Accuracy 0.8571428656578064, Average Loss: 0.32707587842430386
# Epoch 21, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.09746327996253967
# Epoch 22, Training Average Accuracy 0.9375, Average Loss: 0.1945779320916959
# Epoch 22, Validation Average Accuracy 1.0, Average Loss: 0.09755010902881622
# Epoch 23, Training Average Accuracy 0.9375, Average Loss: 0.18602523606802737
# Epoch 23, Validation Average Accuracy 1.0, Average Loss: 0.09679788102706273
# Epoch 24, Training Average Accuracy 0.9107142686843872, Average Loss: 0.23866376919405802
# Epoch 24, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.12425898015499115
# Epoch 25, Training Average Accuracy 0.9553571343421936, Average Loss: 0.15072953621191637
# Epoch 25, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.09830629825592041
# Epoch 26, Training Average Accuracy 0.9375, Average Loss: 0.17357201342071807
# Epoch 26, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.11421137675642967
# Epoch 27, Training Average Accuracy 0.9821428656578064, Average Loss: 0.12048025775168623
# Epoch 27, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.11610258494814236
# Epoch 28, Training Average Accuracy 0.9107142686843872, Average Loss: 0.1880962885916233
# Epoch 28, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.08874028424421947
# Epoch 29, Training Average Accuracy 0.9017857313156128, Average Loss: 0.22643082961440086
# Epoch 29, Validation Average Accuracy 1.0, Average Loss: 0.07028042400876681
# Model saved for fold 4 at trained_models/AKI_BINN\model_fold_4.pth
# Starting fold 5
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.5535714030265808, Average Loss: 0.7533028679234641
# Epoch 0, Validation Average Accuracy 0.5416666865348816, Average Loss: 0.6914812922477722
# Epoch 1, Training Average Accuracy 0.6696428656578064, Average Loss: 0.6324125123875481
# Epoch 1, Validation Average Accuracy 0.5416666865348816, Average Loss: 0.6858593622843424
# Epoch 2, Training Average Accuracy 0.6428571343421936, Average Loss: 0.6209781787225178
# Epoch 2, Validation Average Accuracy 0.5416666865348816, Average Loss: 0.6457563837369283
# Epoch 3, Training Average Accuracy 0.75, Average Loss: 0.5256861405713218
# Epoch 3, Validation Average Accuracy 0.875, Average Loss: 0.4494236509005229
# Epoch 4, Training Average Accuracy 0.7410714030265808, Average Loss: 0.5281821702207837
# Epoch 4, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.29595303535461426
# Epoch 5, Training Average Accuracy 0.8214285969734192, Average Loss: 0.45021895851407734
# Epoch 5, Validation Average Accuracy 0.875, Average Loss: 0.24314078191916147
# Epoch 6, Training Average Accuracy 0.8214285969734192, Average Loss: 0.4314593970775604
# Epoch 6, Validation Average Accuracy 0.9166666865348816, Average Loss: 0.21275368829568228
# Epoch 7, Training Average Accuracy 0.8303571343421936, Average Loss: 0.4212553841727121
# Epoch 7, Validation Average Accuracy 0.875, Average Loss: 0.21696041772762933
# Epoch 8, Training Average Accuracy 0.7767857313156128, Average Loss: 0.4282228159052985
# Epoch 8, Validation Average Accuracy 0.875, Average Loss: 0.21406561881303787
# Epoch 9, Training Average Accuracy 0.8571428656578064, Average Loss: 0.34454113032136646
# Epoch 9, Validation Average Accuracy 0.875, Average Loss: 0.18484931190808615
# Epoch 10, Training Average Accuracy 0.8214285969734192, Average Loss: 0.37210460752248764
# Epoch 10, Validation Average Accuracy 1.0, Average Loss: 0.12536411235729852
# Epoch 11, Training Average Accuracy 0.8660714030265808, Average Loss: 0.3446896533880915
# Epoch 11, Validation Average Accuracy 0.9583333134651184, Average Loss: 0.13105865567922592
# Epoch 12, Training Average Accuracy 0.8839285969734192, Average Loss: 0.31391841013516697
# Epoch 12, Validation Average Accuracy 0.875, Average Loss: 0.15693465992808342
# Epoch 13, Training Average Accuracy 0.9285714030265808, Average Loss: 0.2803706718342645
# Epoch 13, Validation Average Accuracy 1.0, Average Loss: 0.11458744357029597
# Epoch 14, Training Average Accuracy 0.9196428656578064, Average Loss: 0.27038788742252756
# Epoch 14, Validation Average Accuracy 1.0, Average Loss: 0.11536160111427307
# Epoch 15, Training Average Accuracy 0.875, Average Loss: 0.27838779400501934
# Epoch 15, Validation Average Accuracy 1.0, Average Loss: 0.11218784252802531
# Epoch 16, Training Average Accuracy 0.8660714030265808, Average Loss: 0.3052595209862505
# Epoch 16, Validation Average Accuracy 1.0, Average Loss: 0.11330082143346469
# Epoch 17, Training Average Accuracy 0.9196428656578064, Average Loss: 0.20740023122302123
# Epoch 17, Validation Average Accuracy 1.0, Average Loss: 0.0790022537112236
# Epoch 18, Training Average Accuracy 0.9285714030265808, Average Loss: 0.22469704252268588
# Epoch 18, Validation Average Accuracy 1.0, Average Loss: 0.05756689856449763
# Epoch 19, Training Average Accuracy 0.9464285969734192, Average Loss: 0.19805605922426497
# Epoch 19, Validation Average Accuracy 1.0, Average Loss: 0.052578010906775795
# Epoch 20, Training Average Accuracy 0.9107142686843872, Average Loss: 0.24474019424191543
# Epoch 20, Validation Average Accuracy 1.0, Average Loss: 0.062380210806926094
# Epoch 21, Training Average Accuracy 0.9375, Average Loss: 0.20913176504629
# Epoch 21, Validation Average Accuracy 1.0, Average Loss: 0.04550400252143542
# Epoch 22, Training Average Accuracy 0.9375, Average Loss: 0.19812471100262233
# Epoch 22, Validation Average Accuracy 1.0, Average Loss: 0.05083621355394522
# Epoch 23, Training Average Accuracy 0.9464285969734192, Average Loss: 0.19170120198811805
# Epoch 23, Validation Average Accuracy 1.0, Average Loss: 0.043923898289601006
# Epoch 24, Training Average Accuracy 0.9553571343421936, Average Loss: 0.17225343946899688
# Epoch 24, Validation Average Accuracy 1.0, Average Loss: 0.03863769955933094
# Epoch 25, Training Average Accuracy 0.9464285969734192, Average Loss: 0.18633920992059366
# Epoch 25, Validation Average Accuracy 1.0, Average Loss: 0.03343248864014944
# Epoch 26, Training Average Accuracy 0.9553571343421936, Average Loss: 0.15048966210867679
# Epoch 26, Validation Average Accuracy 1.0, Average Loss: 0.04435219429433346
# Epoch 27, Training Average Accuracy 0.9464285969734192, Average Loss: 0.21299193879323347
# Epoch 27, Validation Average Accuracy 1.0, Average Loss: 0.03102586604654789
# Epoch 28, Training Average Accuracy 0.9375, Average Loss: 0.20218759296195848
# Epoch 28, Validation Average Accuracy 1.0, Average Loss: 0.031860913460453354
# Epoch 29, Training Average Accuracy 0.875, Average Loss: 0.24637525475450925
# Epoch 29, Validation Average Accuracy 1.0, Average Loss: 0.038448539872964226
# Model saved for fold 5 at trained_models/AKI_BINN\model_fold_5.pth

# %% [markdown]
# ### Print metrics and scors

# %%
trg.print_val_results(results)
trg.plot_confusion_matrix(results)
trg.plot_results(results, 5)
# Out:
# Average validation accuracy: 0.983 +/- 0.02
# Average validation roc_auc: 1.0 +/- 0.0
# Average validation f1_macro: 0.983 +/- 0.02
# Average validation f1_phen1: 0.983 +/- 0.02
# Average validation f1_phen2: 0.983 +/- 0.02
# Average validation recall_phen1: 0.982 +/- 0.04
# Average validation recall_phen2: 0.982 +/- 0.04
# Average validation precision_phen1: 0.986 +/- 0.03
# Average validation precision_phen2: 0.986 +/- 0.03

# %% [markdown]
# ### Testing of the AKI data

# %%
# Test

num_folds = 5  
model_save_dir = "trained_models/AKI_BINN"  

# Load test data analogue to the train part
protein_matrix_test = fit_data_matrix_to_network_input(test_input_data, features=network.inputs)
X_test, y_test = generate_data(protein_matrix_test, design_matrix=test_design_matrix)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)  # tryout long instead of int16
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=8)  # Adjust batch size as needed

# get the predictions
all_predictions = []

# We go through each of the 5 cv models and get the predictions
for fold in range(1, num_folds + 1):
    model_path = f"{model_save_dir}/model_fold_{fold}.pth"
    model = binn_aki 
    model.load_state_dict(torch.load(model_path))
    model.eval()
    model.to(binn_aki.device)

    fold_predictions = []
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.to(binn_aki.device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            fold_predictions.extend(predicted.cpu().numpy())

    all_predictions.append(fold_predictions)


all_predictions = list(map(list, zip(*all_predictions)))
# majority voting
majority_votes = [Counter(sample_predictions).most_common(1)[0][0] for sample_predictions in all_predictions]

# accuracy
y_test = y_test_tensor.numpy()  # Convert to numpy if it's a tensor
correct = sum(1 for true, pred in zip(y_test, majority_votes) if true == pred)
accuracy = 100 * correct / len(y_test)

# cm, roc and other metrics
test_confusion_matrix = confusion_matrix(y_test, majority_votes, labels=[0, 1])

test_roc_auc = roc_auc_score(y_test, majority_votes)

recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macro = trg.calculate_metrics(test_confusion_matrix)



# Print metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test ROC_AUC: {test_roc_auc:.4f}")
print(f"Test F1 Macro: {f1_macro:.4f}")
print(f"Test F1 Phen1: {f1_phen1:.4f}")
print(f"Test F1 Phen2: {f1_phen2:.4f}")
print(f"Test Recall Phen1: {recall_phen1:.4f}")
print(f"Test Recall Phen2: {recall_phen2:.4f}")
trg.plot_confusion_matrix(test_confusion_matrix, use = 'test')
# Out:
# dasdf
# Test Accuracy: 0.8980
# Test ROC_AUC: 0.9286
# Test F1 Macro: 0.8858
# Test F1 Phen1: 0.9231
# Test F1 Phen2: 0.8485
# Test Recall Phen1: 0.8571
# Test Recall Phen2: 1.0000

# %% [markdown]
# ### Interpreting the BINN

# %% [markdown]
# - We will use explain all 5 CV model seperataly and average, this is somewhat similar to the binn documentation to robustness and the binn.explain_average except that we dont explain the same model 5 times but explain the 5 CV and average over them

# %%
# Interpreting
network = Network(
    input_data    =   train_input_data, 
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein", 
    source_column = "child", 
    target_column = "parent",
    subset_pathways = True 
    )
binn = BINN(
        network=network,
        n_layers=4,
        dropout=0.2,
        validate=False,
        residual=False,
        device="cpu",
        learning_rate=0.001
    )

protein_matrix = fit_data_matrix_to_network_input(train_input_data, features=network.inputs)
X, y = generate_data(protein_matrix, design_matrix=train_design_matrix)

num_folds = 5  
model_save_dir = "trained_models/AKI_BINN"  
explanations = []

test_data = torch.tensor(X, dtype=torch.float32)
background_data = torch.tensor(X, dtype=torch.float32)

for fold in range(1, num_folds + 1):
    model_path = f"{model_save_dir}/model_fold_{fold}.pth"
    model = binn 
    model.load_state_dict(torch.load(model_path)) 
    model.eval()

    explainer = BINNExplainer(model)
    importance_df = explainer.explain(test_data, background_data)
    explanations.append(importance_df)
# Out:
# BINN is on the device: cpu
# dasdf

# %%
### This is done in a similar ways as in the binn documentation example so the data has the same format

# Prepare the data to be explained
concatenated_values = pd.DataFrame()

for i in range(len(explanations) - 1):
    value_column = explanations[i]['value'].rename(f'value{i}')
    concatenated_values = pd.concat([concatenated_values, value_column], axis=1)

df = explanations[-1]

for column in concatenated_values.columns:
    df.insert(loc=df.columns.get_loc('value'), column=column, value=concatenated_values[column])

df.rename(columns={'value': 'value4'}, inplace=True)

df['value_mean'] = df[['value0', 'value1', 'value2', 'value3', 'value4']].mean(axis=1)
df['values_std'] = df[['value0', 'value1', 'value2', 'value3', 'value4']].std(axis=1)

df['value'] = df['value_mean']

# Drop if the source == target, aka the pathways/protein explains itself
df["copy"] = df.apply(lambda x: True if x["source name"] == x["target name"] else False, axis=1)
df = df[df["copy"] == False]

# %%
# Returns a df with mean = mean rank -> lower better
# Code from the binn documentation
importance_df_copy = df.groupby(["source name", "source layer", "target layer"], as_index=False).mean(numeric_only=True)
mean_ranks = []
std_ranks = []
source_layer = []
sources = []
for layer in range(binn.n_layers):
    layer_df = importance_df_copy[importance_df_copy["source layer"] == layer].copy()
    for i in range(5):
        layer_df.sort_values(f"value{i}", ascending=False, inplace=True)
        layer_df[f"rank_{i}"] = range(len(layer_df.index))
    rank_cols = [c for c in layer_df.columns if c.startswith("rank")]
    mean_ranks += (layer_df[rank_cols].mean(axis=1)/ len(layer_df.index)).tolist()
    sources += layer_df["source name"].tolist()
    std_ranks  += (layer_df[rank_cols].std(axis=1)/ len(layer_df.index)).tolist()
    source_layer += layer_df["source layer"].tolist()
plot_df = pd.DataFrame({"mean":mean_ranks, "std":std_ranks, "source layer":source_layer, "source":sources})
plot_df.sort_values("mean").head(20)
# Out:
#           mean       std  source layer         source
# 0     0.003118  0.003378             0         P04114
# 450   0.004560  0.003714             1   R-HSA-140534
# 2     0.006236  0.010375             0         P04908
# 3     0.008018  0.008274             0         P02647
# 758   0.008494  0.005727             2  R-HSA-5357769
# 10    0.009354  0.007454             0         P60709
# 7     0.012027  0.002988             0         P08571
# 1     0.012472  0.011202             0         Q96A08
# 1017  0.015517  0.007213             3   R-HSA-109581
# 459   0.023453  0.018769             1   R-HSA-114608
# 451   0.025407  0.014640             1    R-HSA-68616
# 1015  0.025862  0.025862             3   R-HSA-174824
# 37    0.028062  0.031204             0         P68871
# 474   0.031922  0.042308             1  R-HSA-5696394
# 5     0.032517  0.025079             0         P00734
# 763   0.035521  0.041351             2   R-HSA-212436
# 16    0.036080  0.019055             0         P23141
# 21    0.036080  0.011616             0         P28072
# 13    0.038307  0.023644             0         P49721
# 11    0.041425  0.015155             0         P07998

# %% [markdown]
# ### Covid
# - we train 5-fold-cv
# - The code is the same as for the AKI only the data is different!!!!

# %%
### Training with k=5 CV
# Initiate network

# Same as in the AKI just different data
network = Network(
    input_data    =   covid_train, 
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein", 
    source_column = "child", 
    target_column = "parent",
    subset_pathways = True 
    )
binn = BINN(
    network=network,
    n_layers=4,
    dropout=0.2,
    validate=False,
    residual=False,
    device="cpu",
    learning_rate=0.001
)

protein_matrix = fit_data_matrix_to_network_input(covid_train, features=network.inputs)
X, y = generate_data(protein_matrix, design_matrix=covid_train_design)

X_tensor = torch.tensor(X, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.int16)

model_save_dir = "trained_models/Covid_BINN"
os.makedirs(model_save_dir, exist_ok=True)

kf = KFold(n_splits=5, shuffle=True, random_state=42)

num_epochs = 30
fold = 0
results = {}

for train_index, val_index in kf.split(X_tensor):
    fold += 1
    print(f"Starting fold {fold}")
    
    network = Network(
    input_data    =   covid_train, 
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein",
    source_column = "child", 
    target_column = "parent",
    subset_pathways = True 
    )
    binn_covid = BINN(
        network=network,
        n_layers=4,
        dropout=0.2,
        validate=False,
        residual=False,
        device="cpu",
        learning_rate=0.001
    )

    X_train, X_val = X_tensor[train_index], X_tensor[val_index]
    y_train, y_val = y_tensor[train_index], y_tensor[val_index]

    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    

    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, drop_last=True)

    optimizer = binn_covid.configure_optimizers()[0][0]
    
    # results dict
    results[fold] = {'train_loss': [], 'val_loss': [], 'train_accuracy': [], 'val_accuracy': [], "train_f1_macro":  [], "val_f1_macro":  [], "train_roc_auc": [], "val_roc_auc": [],
                     'train_f1_phen1': [], 'train_f1_phen2': [], 'train_recall_phen1': [], 'train_recall_phen2': [], 'train_precision_phen1': [], 'train_precision_phen2': [],
                     'val_f1_phen1': [], 'val_f1_phen2': [], 'val_recall_phen1': [], 'val_recall_phen2': [], 'val_precision_phen1': [], 'val_precision_phen2': [],"val_cm":[]
                     }
    # for best epoch needed later for plotting results
    best_val_loss = np.inf
    best_epoch = -1
    best_model_state = None

    for epoch in range(num_epochs):
        # Training
        binn_covid.train()
        total_loss = 0.0
        total_accuracy = 0

        train_true_labels = []
        train_predictions = []

        val_true_labels = []
        val_predictions = []

        for inputs, targets in train_loader:
            inputs = inputs.to(binn_covid.device)
            targets = targets.to(binn_covid.device).type(torch.LongTensor)
            optimizer.zero_grad()
            outputs = binn_covid(inputs)
            loss = F.cross_entropy(outputs, targets)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            total_accuracy += torch.sum(torch.argmax(outputs, axis=1) == targets) / len(targets)

            train_true_labels.append(targets.cpu().numpy())
            train_predictions.append(outputs.cpu().detach().numpy())  

        train_true_labels = np.concatenate(train_true_labels)
        train_logits = np.concatenate(train_predictions, axis=0)
        train_probs = torch.softmax(torch.tensor(train_logits), dim=1).numpy()  # Assuming binary classification
        train_roc_auc = roc_auc_score(train_true_labels, train_probs[:, 1])
        
        train_pred_labels = np.argmax(train_probs, axis=1)
        

        # Get the metrics
        train_cm = confusion_matrix(train_true_labels, train_pred_labels)
        train_metrics = trg.calculate_metrics(train_cm)
        recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macro = train_metrics
        # loss and accuracy
        avg_loss = total_loss / len(train_loader)
        avg_accuracy = total_accuracy / len(train_loader)

        # add results
        results[fold]['train_loss'].append(avg_loss)
        results[fold]['train_accuracy'].append(accuracy.item())  # Ensure it's a scalar
        results[fold]['train_f1_macro'].append(f1_macro)
        results[fold]['train_roc_auc'].append(train_roc_auc)
        results[fold]['train_f1_phen1'].append(f1_phen1)
        results[fold]['train_f1_phen2'].append(f1_phen2)
        results[fold]['train_recall_phen1'].append(recall_phen1)
        results[fold]['train_recall_phen2'].append(recall_phen2)
        results[fold]['train_precision_phen1'].append(precision_phen1)
        results[fold]['train_precision_phen2'].append(precision_phen2)
        #############
        
        print(f'Epoch {epoch}, Training Average Accuracy {avg_accuracy}, Average Loss: {avg_loss}')

        # Validation
        binn_covid.eval()
        val_loss = 0.0
        val_accuracy = 0

        with torch.no_grad():
            for inputs, targets in val_loader:
                inputs = inputs.to(binn_covid.device)
                targets = targets.to(binn_covid.device).type(torch.LongTensor)
                outputs = binn_covid(inputs)
                loss = F.cross_entropy(outputs, targets)
                val_loss += loss.item()
                val_accuracy += torch.sum(torch.argmax(outputs, axis=1) == targets) / len(targets)

                val_true_labels.append(targets.cpu().numpy())
                val_predictions.append(outputs.cpu().detach().numpy())  

        val_true_labels = np.concatenate(val_true_labels)
        val_logits = np.concatenate(val_predictions, axis=0)
        val_probs = torch.softmax(torch.tensor(val_logits), dim=1).numpy()  # Assuming binary classification
        val_roc_auc = roc_auc_score(val_true_labels, val_probs[:, 1])
        
        val_pred_labels = np.argmax(val_probs, axis=1)
        val_cm = confusion_matrix(val_true_labels, val_pred_labels)
        val_metrics = trg.calculate_metrics(val_cm) 
        recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macr = val_metrics       
        avg_val_loss = val_loss / len(val_loader)
        avg_val_accuracy = val_accuracy / len(val_loader)
        print(f'Epoch {epoch}, Validation Average Accuracy {avg_val_accuracy}, Average Loss: {avg_val_loss}')
        
        # validation
        results[fold]['val_loss'].append(avg_val_loss)
        results[fold]['val_accuracy'].append(accuracy.item())  # Ensure it's a scalar
        results[fold]['val_f1_macro'].append(f1_macr)
        results[fold]['val_roc_auc'].append(val_roc_auc)
        results[fold]['val_f1_phen1'].append(f1_phen1)
        results[fold]['val_f1_phen2'].append(f1_phen2)
        results[fold]['val_recall_phen1'].append(recall_phen1)
        results[fold]['val_recall_phen2'].append(recall_phen2)
        results[fold]['val_precision_phen1'].append(precision_phen1)
        results[fold]['val_precision_phen2'].append(precision_phen2)
        results[fold]['val_cm'].append(val_cm)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_epoch = epoch
            best_model_state = binn_covid.state_dict().copy()

    if best_model_state is not None:
        model_save_path = os.path.join(model_save_dir, f"best_model_fold_{fold}.pth")
        torch.save(best_model_state, model_save_path)
    results[fold]['best_val_epoch'] = best_epoch
    # Safe the 5 models in the folder
    model_save_path = os.path.join(model_save_dir, f"model_fold_{fold}.pth")
    torch.save(binn_covid.state_dict(), model_save_path)

    print(f"Model saved for fold {fold} at {model_save_path}")
# Out:
# BINN is on the device: cpu
# dasdf
# Starting fold 1
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.6232143044471741, Average Loss: 0.6652298544134413
# Epoch 0, Validation Average Accuracy 0.779411792755127, Average Loss: 0.5242256995509652
# Epoch 1, Training Average Accuracy 0.7178571224212646, Average Loss: 0.5660371980496816
# Epoch 1, Validation Average Accuracy 0.8308823704719543, Average Loss: 0.3992438211160548
# Epoch 2, Training Average Accuracy 0.7285714149475098, Average Loss: 0.5409155879701887
# Epoch 2, Validation Average Accuracy 0.845588207244873, Average Loss: 0.37692562446874733
# Epoch 3, Training Average Accuracy 0.7732142806053162, Average Loss: 0.4836348525115422
# Epoch 3, Validation Average Accuracy 0.845588207244873, Average Loss: 0.37102047836079316
# Epoch 4, Training Average Accuracy 0.7660714387893677, Average Loss: 0.4901095096554075
# Epoch 4, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3723988313885296
# Epoch 5, Training Average Accuracy 0.7946428656578064, Average Loss: 0.45130777209997175
# Epoch 5, Validation Average Accuracy 0.8308823704719543, Average Loss: 0.368842521791949
# Epoch 6, Training Average Accuracy 0.8357142806053162, Average Loss: 0.41987896487116816
# Epoch 6, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.33562961439875993
# Epoch 7, Training Average Accuracy 0.8446428775787354, Average Loss: 0.38137087374925616
# Epoch 7, Validation Average Accuracy 0.875, Average Loss: 0.33012792599551816
# Epoch 8, Training Average Accuracy 0.8125, Average Loss: 0.42333429338676587
# Epoch 8, Validation Average Accuracy 0.875, Average Loss: 0.31205843520515103
# Epoch 9, Training Average Accuracy 0.8125, Average Loss: 0.39458283334970473
# Epoch 9, Validation Average Accuracy 0.845588207244873, Average Loss: 0.34604285876540575
# Epoch 10, Training Average Accuracy 0.824999988079071, Average Loss: 0.3968155603323664
# Epoch 10, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.30470010638237
# Epoch 11, Training Average Accuracy 0.8321428298950195, Average Loss: 0.39530270525387357
# Epoch 11, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.32154377725194483
# Epoch 12, Training Average Accuracy 0.8125, Average Loss: 0.39124982495393074
# Epoch 12, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.2977363852893605
# Epoch 13, Training Average Accuracy 0.8071428537368774, Average Loss: 0.4113063565322331
# Epoch 13, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2911118615199538
# Epoch 14, Training Average Accuracy 0.8500000238418579, Average Loss: 0.36289261632731984
# Epoch 14, Validation Average Accuracy 0.875, Average Loss: 0.30453583817271623
# Epoch 15, Training Average Accuracy 0.8357142806053162, Average Loss: 0.38571288660168646
# Epoch 15, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.31101554544533
# Epoch 16, Training Average Accuracy 0.8232142925262451, Average Loss: 0.4086429400103433
# Epoch 16, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.33459120747797627
# Epoch 17, Training Average Accuracy 0.8214285969734192, Average Loss: 0.37895589683737074
# Epoch 17, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.3183967576307409
# Epoch 18, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3795169127838952
# Epoch 18, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.3144109192139962
# Epoch 19, Training Average Accuracy 0.8357142806053162, Average Loss: 0.394340710288712
# Epoch 19, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.2604459815603845
# Epoch 20, Training Average Accuracy 0.8517857193946838, Average Loss: 0.3436993016728333
# Epoch 20, Validation Average Accuracy 0.8308823704719543, Average Loss: 0.32436637821442943
# Epoch 21, Training Average Accuracy 0.8464285731315613, Average Loss: 0.3626744961099965
# Epoch 21, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2661110942854601
# Epoch 22, Training Average Accuracy 0.8232142925262451, Average Loss: 0.40592105654733524
# Epoch 22, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.28593499651726556
# Epoch 23, Training Average Accuracy 0.8142856955528259, Average Loss: 0.40252344555088454
# Epoch 23, Validation Average Accuracy 0.875, Average Loss: 0.2625521307482439
# Epoch 24, Training Average Accuracy 0.8535714149475098, Average Loss: 0.33527736562703336
# Epoch 24, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.29150000784327
# Epoch 25, Training Average Accuracy 0.8464285731315613, Average Loss: 0.36057314297982623
# Epoch 25, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.3298084268017727
# Epoch 26, Training Average Accuracy 0.8607142567634583, Average Loss: 0.34352386349013875
# Epoch 26, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.28343000175321803
# Epoch 27, Training Average Accuracy 0.8357142806053162, Average Loss: 0.37165384739637375
# Epoch 27, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.25863472503774304
# Epoch 28, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3443306736648083
# Epoch 28, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.2630067949785906
# Epoch 29, Training Average Accuracy 0.8374999761581421, Average Loss: 0.36003219495926586
# Epoch 29, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.2623732810949578
# Model saved for fold 1 at trained_models/Covid_BINN\model_fold_1.pth
# Starting fold 2
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.6678571701049805, Average Loss: 0.6136785302843366
# Epoch 0, Validation Average Accuracy 0.7132353186607361, Average Loss: 0.5548672746209538
# Epoch 1, Training Average Accuracy 0.7357142567634583, Average Loss: 0.5426590634243829
# Epoch 1, Validation Average Accuracy 0.7720588445663452, Average Loss: 0.5003718584775925
# Epoch 2, Training Average Accuracy 0.7696428298950195, Average Loss: 0.49083868988922663
# Epoch 2, Validation Average Accuracy 0.8235294222831726, Average Loss: 0.43231210638495055
# Epoch 3, Training Average Accuracy 0.7785714268684387, Average Loss: 0.4486222626907485
# Epoch 3, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3861028135699384
# Epoch 4, Training Average Accuracy 0.8214285969734192, Average Loss: 0.42529849857091906
# Epoch 4, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3909800810848965
# Epoch 5, Training Average Accuracy 0.8053571581840515, Average Loss: 0.41066020929387637
# Epoch 5, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.37075556727016673
# Epoch 6, Training Average Accuracy 0.8214285969734192, Average Loss: 0.401842047061239
# Epoch 6, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.365329566247323
# Epoch 7, Training Average Accuracy 0.8178571462631226, Average Loss: 0.3903156748839787
# Epoch 7, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.3785346715765841
# Epoch 8, Training Average Accuracy 0.8142856955528259, Average Loss: 0.3855067666087832
# Epoch 8, Validation Average Accuracy 0.845588207244873, Average Loss: 0.3609636070973733
# Epoch 9, Training Average Accuracy 0.8303571343421936, Average Loss: 0.39826840641243116
# Epoch 9, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.3565230869195041
# Epoch 10, Training Average Accuracy 0.8267857432365417, Average Loss: 0.3997958681413106
# Epoch 10, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3575725743875784
# Epoch 11, Training Average Accuracy 0.8446428775787354, Average Loss: 0.36667070388793943
# Epoch 11, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.3393232265816015
# Epoch 12, Training Average Accuracy 0.8535714149475098, Average Loss: 0.35307852114949906
# Epoch 12, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.34072700537302913
# Epoch 13, Training Average Accuracy 0.8392857313156128, Average Loss: 0.351145388931036
# Epoch 13, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3466027054716559
# Epoch 14, Training Average Accuracy 0.8482142686843872, Average Loss: 0.38269355158720697
# Epoch 14, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.33441032600753445
# Epoch 15, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3506586695356028
# Epoch 15, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.3297279227305861
# Epoch 16, Training Average Accuracy 0.8428571224212646, Average Loss: 0.37132715455123355
# Epoch 16, Validation Average Accuracy 0.875, Average Loss: 0.3325716362280004
# Epoch 17, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3751321061381272
# Epoch 17, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.36851365491747856
# Epoch 18, Training Average Accuracy 0.8642857074737549, Average Loss: 0.3289649870778833
# Epoch 18, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.33118893556735096
# Epoch 19, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3550307884812355
# Epoch 19, Validation Average Accuracy 0.875, Average Loss: 0.31422162669546466
# Epoch 20, Training Average Accuracy 0.8517857193946838, Average Loss: 0.32723716774157113
# Epoch 20, Validation Average Accuracy 0.9117646813392639, Average Loss: 0.3109142368330675
# Epoch 21, Training Average Accuracy 0.875, Average Loss: 0.309132039227656
# Epoch 21, Validation Average Accuracy 0.9117646813392639, Average Loss: 0.3152281563071644
# Epoch 22, Training Average Accuracy 0.8607142567634583, Average Loss: 0.3222644917666912
# Epoch 22, Validation Average Accuracy 0.875, Average Loss: 0.34075875142041373
# Epoch 23, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3788589494568961
# Epoch 23, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.32866012699463787
# Epoch 24, Training Average Accuracy 0.8357142806053162, Average Loss: 0.3747415156236717
# Epoch 24, Validation Average Accuracy 0.875, Average Loss: 0.3414030614144662
# Epoch 25, Training Average Accuracy 0.8732143044471741, Average Loss: 0.3330473062183176
# Epoch 25, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.32139279298922596
# Epoch 26, Training Average Accuracy 0.8517857193946838, Average Loss: 0.34844964018889835
# Epoch 26, Validation Average Accuracy 0.845588207244873, Average Loss: 0.32401592569316134
# Epoch 27, Training Average Accuracy 0.8464285731315613, Average Loss: 0.3597374479685511
# Epoch 27, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.2984827156452572
# Epoch 28, Training Average Accuracy 0.8303571343421936, Average Loss: 0.3500197459544454
# Epoch 28, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.3207889199256897
# Epoch 29, Training Average Accuracy 0.8714285492897034, Average Loss: 0.3198496147990227
# Epoch 29, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.3008962657083483
# Model saved for fold 2 at trained_models/Covid_BINN\model_fold_2.pth
# Starting fold 3
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.47857141494750977, Average Loss: 0.8364522640194212
# Epoch 0, Validation Average Accuracy 0.7867646813392639, Average Loss: 0.5720959112924688
# Epoch 1, Training Average Accuracy 0.6785714030265808, Average Loss: 0.5975677204983575
# Epoch 1, Validation Average Accuracy 0.875, Average Loss: 0.38170426032122445
# Epoch 2, Training Average Accuracy 0.7482143044471741, Average Loss: 0.5214987722890717
# Epoch 2, Validation Average Accuracy 0.8308823704719543, Average Loss: 0.3616285906995044
# Epoch 3, Training Average Accuracy 0.7785714268684387, Average Loss: 0.4821188561618328
# Epoch 3, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.29451241651002097
# Epoch 4, Training Average Accuracy 0.7839285731315613, Average Loss: 0.45989024128232686
# Epoch 4, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.3032957258469918
# Epoch 5, Training Average Accuracy 0.7821428775787354, Average Loss: 0.4529007830790111
# Epoch 5, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.29321568503099327
# Epoch 6, Training Average Accuracy 0.8464285731315613, Average Loss: 0.40519212122474396
# Epoch 6, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.27349880206234317
# Epoch 7, Training Average Accuracy 0.8089285492897034, Average Loss: 0.4165132384215082
# Epoch 7, Validation Average Accuracy 0.904411792755127, Average Loss: 0.2887942422838772
# Epoch 8, Training Average Accuracy 0.8357142806053162, Average Loss: 0.40846282137291773
# Epoch 8, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.28914353251457214
# Epoch 9, Training Average Accuracy 0.8160714507102966, Average Loss: 0.42874688005873135
# Epoch 9, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.28882468732840877
# Epoch 10, Training Average Accuracy 0.8285714387893677, Average Loss: 0.38436844487275396
# Epoch 10, Validation Average Accuracy 0.9117646813392639, Average Loss: 0.26809709343840094
# Epoch 11, Training Average Accuracy 0.8321428298950195, Average Loss: 0.3859684159713132
# Epoch 11, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.2641150166883188
# Epoch 12, Training Average Accuracy 0.8339285850524902, Average Loss: 0.36904536272798266
# Epoch 12, Validation Average Accuracy 0.875, Average Loss: 0.29354259831940427
# Epoch 13, Training Average Accuracy 0.8446428775787354, Average Loss: 0.35940634161233903
# Epoch 13, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.28366704066010084
# Epoch 14, Training Average Accuracy 0.8392857313156128, Average Loss: 0.3687978282570839
# Epoch 14, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.29946942364468293
# Epoch 15, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3495855069586209
# Epoch 15, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.26471668043557334
# Epoch 16, Training Average Accuracy 0.8482142686843872, Average Loss: 0.35736024869339805
# Epoch 16, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.27192002819741473
# Epoch 17, Training Average Accuracy 0.8392857313156128, Average Loss: 0.3686674990824291
# Epoch 17, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2774493777576615
# Epoch 18, Training Average Accuracy 0.8374999761581421, Average Loss: 0.37919861684952466
# Epoch 18, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2731779743643368
# Epoch 19, Training Average Accuracy 0.8517857193946838, Average Loss: 0.33949486847434723
# Epoch 19, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.25648507870295467
# Epoch 20, Training Average Accuracy 0.8517857193946838, Average Loss: 0.3439494819513389
# Epoch 20, Validation Average Accuracy 0.875, Average Loss: 0.29327189966159706
# Epoch 21, Training Average Accuracy 0.8464285731315613, Average Loss: 0.3348338335752487
# Epoch 21, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.2823326649034725
# Epoch 22, Training Average Accuracy 0.8285714387893677, Average Loss: 0.34463110943990094
# Epoch 22, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2641298442202456
# Epoch 23, Training Average Accuracy 0.8553571701049805, Average Loss: 0.3531748291637216
# Epoch 23, Validation Average Accuracy 0.875, Average Loss: 0.28106584115063443
# Epoch 24, Training Average Accuracy 0.875, Average Loss: 0.33150959483214787
# Epoch 24, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2686522375134861
# Epoch 25, Training Average Accuracy 0.8803571462631226, Average Loss: 0.32034814485481805
# Epoch 25, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.25286771598107677
# Epoch 26, Training Average Accuracy 0.8446428775787354, Average Loss: 0.35914400784032685
# Epoch 26, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.25305430393885164
# Epoch 27, Training Average Accuracy 0.8446428775787354, Average Loss: 0.3336719688560281
# Epoch 27, Validation Average Accuracy 0.904411792755127, Average Loss: 0.25149552918532314
# Epoch 28, Training Average Accuracy 0.8410714268684387, Average Loss: 0.3546261840632984
# Epoch 28, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.26203134327250366
# Epoch 29, Training Average Accuracy 0.862500011920929, Average Loss: 0.3329874400581632
# Epoch 29, Validation Average Accuracy 0.9191176295280457, Average Loss: 0.23727123768014066
# Model saved for fold 3 at trained_models/Covid_BINN\model_fold_3.pth
# Starting fold 4
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.5767857432365417, Average Loss: 0.7439881384372711
# Epoch 0, Validation Average Accuracy 0.7647058963775635, Average Loss: 0.5101825209224925
# Epoch 1, Training Average Accuracy 0.625, Average Loss: 0.6433292997734887
# Epoch 1, Validation Average Accuracy 0.8308823704719543, Average Loss: 0.37843379290664897
# Epoch 2, Training Average Accuracy 0.7357142567634583, Average Loss: 0.5701472569789205
# Epoch 2, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.3403483041945626
# Epoch 3, Training Average Accuracy 0.737500011920929, Average Loss: 0.5318549962980407
# Epoch 3, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.33652496863813963
# Epoch 4, Training Average Accuracy 0.7642857432365417, Average Loss: 0.4991466128400394
# Epoch 4, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.2888292849940412
# Epoch 5, Training Average Accuracy 0.7946428656578064, Average Loss: 0.46424543942723956
# Epoch 5, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2967856767423013
# Epoch 6, Training Average Accuracy 0.7982142567634583, Average Loss: 0.46685618502753123
# Epoch 6, Validation Average Accuracy 0.875, Average Loss: 0.2813294253805104
# Epoch 7, Training Average Accuracy 0.8285714387893677, Average Loss: 0.4006816685199738
# Epoch 7, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.27867643710444956
# Epoch 8, Training Average Accuracy 0.8160714507102966, Average Loss: 0.41976755900042395
# Epoch 8, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.25775891564348163
# Epoch 9, Training Average Accuracy 0.8035714030265808, Average Loss: 0.41851363841976436
# Epoch 9, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2651614846990389
# Epoch 10, Training Average Accuracy 0.8285714387893677, Average Loss: 0.4011358202568122
# Epoch 10, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2664569511133082
# Epoch 11, Training Average Accuracy 0.8232142925262451, Average Loss: 0.3904133398618017
# Epoch 11, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.2503333523431245
# Epoch 12, Training Average Accuracy 0.8089285492897034, Average Loss: 0.41866364181041715
# Epoch 12, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.26079685898388133
# Epoch 13, Training Average Accuracy 0.8267857432365417, Average Loss: 0.4275183568043368
# Epoch 13, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.25798149231602163
# Epoch 14, Training Average Accuracy 0.8053571581840515, Average Loss: 0.46561305629355565
# Epoch 14, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.2458665331496912
# Epoch 15, Training Average Accuracy 0.8428571224212646, Average Loss: 0.38771077916026114
# Epoch 15, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.24276344784918955
# Epoch 16, Training Average Accuracy 0.8196428418159485, Average Loss: 0.4177199776683535
# Epoch 16, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2625422232291278
# Epoch 17, Training Average Accuracy 0.8482142686843872, Average Loss: 0.3822561963328293
# Epoch 17, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.23725705506170497
# Epoch 18, Training Average Accuracy 0.8232142925262451, Average Loss: 0.3922209597059659
# Epoch 18, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.22947371137492797
# Epoch 19, Training Average Accuracy 0.8196428418159485, Average Loss: 0.4054210033799921
# Epoch 19, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2395317685954711
# Epoch 20, Training Average Accuracy 0.8267857432365417, Average Loss: 0.3801964429340192
# Epoch 20, Validation Average Accuracy 0.904411792755127, Average Loss: 0.2237671994987656
# Epoch 21, Training Average Accuracy 0.8374999761581421, Average Loss: 0.39467956572771073
# Epoch 21, Validation Average Accuracy 0.9117646813392639, Average Loss: 0.22931940240018509
# Epoch 22, Training Average Accuracy 0.8446428775787354, Average Loss: 0.392497422013964
# Epoch 22, Validation Average Accuracy 0.9117646813392639, Average Loss: 0.2289354842813576
# Epoch 23, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3445661859852927
# Epoch 23, Validation Average Accuracy 0.9191176295280457, Average Loss: 0.22337991678539446
# Epoch 24, Training Average Accuracy 0.8464285731315613, Average Loss: 0.35087419375777246
# Epoch 24, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.24345865736112876
# Epoch 25, Training Average Accuracy 0.8607142567634583, Average Loss: 0.353903956924166
# Epoch 25, Validation Average Accuracy 0.904411792755127, Average Loss: 0.23092209087575183
# Epoch 26, Training Average Accuracy 0.8374999761581421, Average Loss: 0.357231196974005
# Epoch 26, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.232657544533996
# Epoch 27, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3556712218693325
# Epoch 27, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.25253838651320515
# Epoch 28, Training Average Accuracy 0.8267857432365417, Average Loss: 0.39272554256021974
# Epoch 28, Validation Average Accuracy 0.875, Average Loss: 0.25258755552418094
# Epoch 29, Training Average Accuracy 0.8321428298950195, Average Loss: 0.35757732710668017
# Epoch 29, Validation Average Accuracy 0.875, Average Loss: 0.2466563104706652
# Model saved for fold 4 at trained_models/Covid_BINN\model_fold_4.pth
# Starting fold 5
#
# BINN is on the device: cpu
# Epoch 0, Training Average Accuracy 0.6089285612106323, Average Loss: 0.6886854039771216
# Epoch 0, Validation Average Accuracy 0.7867646813392639, Average Loss: 0.5157956551103031
# Epoch 1, Training Average Accuracy 0.7035714387893677, Average Loss: 0.5822701901197433
# Epoch 1, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.4481052975444233
# Epoch 2, Training Average Accuracy 0.7803571224212646, Average Loss: 0.4878555898155485
# Epoch 2, Validation Average Accuracy 0.845588207244873, Average Loss: 0.420730322599411
# Epoch 3, Training Average Accuracy 0.7785714268684387, Average Loss: 0.4871052020362445
# Epoch 3, Validation Average Accuracy 0.845588207244873, Average Loss: 0.37723979003289165
# Epoch 4, Training Average Accuracy 0.8267857432365417, Average Loss: 0.4290856793522835
# Epoch 4, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.37294839322566986
# Epoch 5, Training Average Accuracy 0.7982142567634583, Average Loss: 0.4353079757520131
# Epoch 5, Validation Average Accuracy 0.8235294222831726, Average Loss: 0.3685467094182968
# Epoch 6, Training Average Accuracy 0.8178571462631226, Average Loss: 0.41925472233976635
# Epoch 6, Validation Average Accuracy 0.8382353186607361, Average Loss: 0.35033948894809275
# Epoch 7, Training Average Accuracy 0.7910714149475098, Average Loss: 0.4367992750235966
# Epoch 7, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3462311458938262
# Epoch 8, Training Average Accuracy 0.8232142925262451, Average Loss: 0.39747304767370223
# Epoch 8, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.32632316385998444
# Epoch 9, Training Average Accuracy 0.8142856955528259, Average Loss: 0.4099866914962019
# Epoch 9, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.317379731027519
# Epoch 10, Training Average Accuracy 0.8535714149475098, Average Loss: 0.3622106672397682
# Epoch 10, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.31524955656598597
# Epoch 11, Training Average Accuracy 0.8732143044471741, Average Loss: 0.3380698971450329
# Epoch 11, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.31840646069716005
# Epoch 12, Training Average Accuracy 0.8374999761581421, Average Loss: 0.36774989228163446
# Epoch 12, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.347821067470838
# Epoch 13, Training Average Accuracy 0.8517857193946838, Average Loss: 0.36316526830196383
# Epoch 13, Validation Average Accuracy 0.8529411554336548, Average Loss: 0.3512837737798691
# Epoch 14, Training Average Accuracy 0.8232142925262451, Average Loss: 0.40642673149704933
# Epoch 14, Validation Average Accuracy 0.8602941036224365, Average Loss: 0.3418355505256092
# Epoch 15, Training Average Accuracy 0.8339285850524902, Average Loss: 0.3897466662739004
# Epoch 15, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.35120026876821236
# Epoch 16, Training Average Accuracy 0.8374999761581421, Average Loss: 0.37113883846572465
# Epoch 16, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.3084016724982682
# Epoch 17, Training Average Accuracy 0.8553571701049805, Average Loss: 0.359394628235272
# Epoch 17, Validation Average Accuracy 0.875, Average Loss: 0.31678959836854653
# Epoch 18, Training Average Accuracy 0.8410714268684387, Average Loss: 0.3809650189110211
# Epoch 18, Validation Average Accuracy 0.875, Average Loss: 0.2995348881710978
# Epoch 19, Training Average Accuracy 0.8482142686843872, Average Loss: 0.36322231771690505
# Epoch 19, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2962547043228851
# Epoch 20, Training Average Accuracy 0.824999988079071, Average Loss: 0.3809652542429311
# Epoch 20, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.30211349094615264
# Epoch 21, Training Average Accuracy 0.8785714507102966, Average Loss: 0.308576858575855
# Epoch 21, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.3046426549553871
# Epoch 22, Training Average Accuracy 0.8321428298950195, Average Loss: 0.3816078811883926
# Epoch 22, Validation Average Accuracy 0.875, Average Loss: 0.292915146359626
# Epoch 23, Training Average Accuracy 0.8642857074737549, Average Loss: 0.31623933533472676
# Epoch 23, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.29275978531907587
# Epoch 24, Training Average Accuracy 0.8767856955528259, Average Loss: 0.3185624370617526
# Epoch 24, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.29636261020513144
# Epoch 25, Training Average Accuracy 0.8571428656578064, Average Loss: 0.33434098192623685
# Epoch 25, Validation Average Accuracy 0.8970588445663452, Average Loss: 0.2752127785454778
# Epoch 26, Training Average Accuracy 0.8339285850524902, Average Loss: 0.36307060207639424
# Epoch 26, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.28772181119112406
# Epoch 27, Training Average Accuracy 0.8464285731315613, Average Loss: 0.364185524306127
# Epoch 27, Validation Average Accuracy 0.8897058963775635, Average Loss: 0.27449287255020705
# Epoch 28, Training Average Accuracy 0.8571428656578064, Average Loss: 0.3328930132091045
# Epoch 28, Validation Average Accuracy 0.8823529481887817, Average Loss: 0.2900458324481459
# Epoch 29, Training Average Accuracy 0.8410714268684387, Average Loss: 0.37036198654345104
# Epoch 29, Validation Average Accuracy 0.8676470518112183, Average Loss: 0.2947413881911951
# Model saved for fold 5 at trained_models/Covid_BINN\model_fold_5.pth

# %%
trg.print_val_results(results)
trg.plot_confusion_matrix(results)
trg.plot_results(results, 5)
# Out:
# Average validation accuracy: 0.875 +/- 0.02
# Average validation roc_auc: 0.956 +/- 0.01
# Average validation f1_macro: 0.873 +/- 0.02
# Average validation f1_phen1: 0.883 +/- 0.03
# Average validation f1_phen2: 0.863 +/- 0.02
# Average validation recall_phen1: 0.905 +/- 0.02
# Average validation recall_phen2: 0.842 +/- 0.04
# Average validation precision_phen1: 0.864 +/- 0.05
# Average validation precision_phen2: 0.887 +/- 0.02

# %% [markdown]
# ### Test Covid data

# %%
num_folds = 5  
model_save_dir = "trained_models/Covid_BINN" 

# Load test data
protein_matrix_test = fit_data_matrix_to_network_input(covid_test, features=network.inputs)
X_test, y_test = generate_data(protein_matrix_test, design_matrix=covid_test_design)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long) 
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=8)  

all_predictions = []

# go through each of the 5 models
for fold in range(1, num_folds + 1):
    model_path = f"{model_save_dir}/model_fold_{fold}.pth"
    model = binn_covid 
    model.load_state_dict(torch.load(model_path))
    model.eval()
    model.to(binn_covid.device)  

    fold_predictions = []
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.to(binn_covid.device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            fold_predictions.extend(predicted.cpu().numpy())

    all_predictions.append(fold_predictions)

all_predictions = list(map(list, zip(*all_predictions)))
majority_votes = [Counter(sample_predictions).most_common(1)[0][0] for sample_predictions in all_predictions]

# Calculate accuracy
y_test = y_test_tensor.numpy()  # Convert to numpy if it's a tensor
correct = sum(1 for true, pred in zip(y_test, majority_votes) if true == pred)
accuracy = 100 * correct / len(y_test)


test_confusion_matrix = confusion_matrix(y_test, majority_votes, labels=[0, 1])

test_roc_auc = roc_auc_score(y_test, majority_votes)

recall_phen1, recall_phen2, precision_phen1, precision_phen2, accuracy, f1_phen1, f1_phen2, f1_macro = trg.calculate_metrics(test_confusion_matrix)



# Print metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test ROC_AUC: {test_roc_auc:.4f}")
print(f"Test F1 Macro: {f1_macro:.4f}")
print(f"Test F1 Phen1: {f1_phen1:.4f}")
print(f"Test F1 Phen2: {f1_phen2:.4f}")
print(f"Test Recall Phen1: {recall_phen1:.4f}")
print(f"Test Recall Phen2: {recall_phen2:.4f}")
trg.plot_confusion_matrix(test_confusion_matrix, use = 'test')
# Out:
# dasdf
# Test Accuracy: 0.8481
# Test ROC_AUC: 0.8469
# Test F1 Macro: 0.8475
# Test F1 Phen1: 0.8571
# Test F1 Phen2: 0.8378
# Test Recall Phen1: 0.8780
# Test Recall Phen2: 0.8158

# %% [markdown]
# ### Interpreting Covid

# %%
network = Network(
    input_data    =   covid_train, 
    pathways      =   pathways,
    mapping       =   translation,
    input_data_column = "Protein", 
    source_column = "child", 
    target_column = "parent",
    subset_pathways = True 
    )
binn = BINN(
        network=network,
        n_layers=4,
        dropout=0.2,
        validate=False,
        residual=False,
        device="cpu",
        learning_rate=0.001
    )

protein_matrix = fit_data_matrix_to_network_input(covid_train, features=network.inputs)
X, y = generate_data(protein_matrix, design_matrix=covid_train_design)

num_folds = 5  
model_save_dir = "trained_models/Covid_BINN"  
explanations = []

test_data = torch.tensor(X, dtype=torch.float32)
background_data = torch.tensor(X, dtype=torch.float32)

for fold in range(1, num_folds + 1):
    model_path = f"{model_save_dir}/model_fold_{fold}.pth"
    model = binn 
    model.load_state_dict(torch.load(model_path)) 
    model.eval()

    explainer = BINNExplainer(model)
    importance_df = explainer.explain(test_data, background_data)
    explanations.append(importance_df)
# Out:
# BINN is on the device: cpu
# dasdf

# %%
# Merge the df
concatenated_values = pd.DataFrame()

for i in range(len(explanations) - 1):
    value_column = explanations[i]['value'].rename(f'value{i}')
    concatenated_values = pd.concat([concatenated_values, value_column], axis=1)

df = explanations[-1]

for column in concatenated_values.columns:
    df.insert(loc=df.columns.get_loc('value'), column=column, value=concatenated_values[column])

df.rename(columns={'value': 'value4'}, inplace=True)
#last_df = last_df.iloc[:, :-5]

df['value_mean'] = df[['value0', 'value1', 'value2', 'value3', 'value4']].mean(axis=1)
df['values_std'] = df[['value0', 'value1', 'value2', 'value3', 'value4']].std(axis=1)

df['value'] = df['value_mean']


# Drop if the source == target, aka the pathways/protein explains itself
df["copy"] = df.apply(lambda x: True if x["source name"] == x["target name"] else False, axis=1)
df = df[df["copy"] == False]

# %%
importance_df_copy = df.groupby(["source name", "source layer", "target layer"], as_index=False).mean(numeric_only=True)
mean_ranks = []
std_ranks = []
source_layer = []
sources = []
for layer in range(binn.n_layers):
    layer_df = importance_df_copy[importance_df_copy["source layer"] == layer].copy()
    for i in range(5):
        layer_df.sort_values(f"value{i}", ascending=False, inplace=True)
        layer_df[f"rank_{i}"] = range(len(layer_df.index))
    rank_cols = [c for c in layer_df.columns if c.startswith("rank")]
    mean_ranks += (layer_df[rank_cols].mean(axis=1)/ len(layer_df.index)).tolist()
    sources += layer_df["source name"].tolist()
    std_ranks  += (layer_df[rank_cols].std(axis=1)/ len(layer_df.index)).tolist()
    source_layer += layer_df["source layer"].tolist()
plot_df = pd.DataFrame({"mean":mean_ranks, "std":std_ranks, "source layer":source_layer, "source":sources})
plot_df.sort_values("mean").head(20)
# Out:
#          mean       std  source layer         source
# 293  0.000000  0.000000             3   R-HSA-168249
# 126  0.004494  0.006154             1   R-HSA-114608
# 0    0.009600  0.013145             0         P02649
# 1    0.016000  0.016000             0         P06396
# 4    0.022400  0.008764             0         P02675
# 131  0.024719  0.026825             1   R-HSA-111465
# 216  0.025316  0.020014             2    R-HSA-76005
# 2    0.028800  0.019267             0         P02671
# 214  0.032911  0.041599             2   R-HSA-166658
# 294  0.036667  0.029814             3  R-HSA-2173782
# 3    0.046400  0.024916             0         P05109
# 7    0.051200  0.015595             0         P00740
# 221  0.055696  0.045287             2    R-HSA-75153
# 219  0.058228  0.077309             2  R-HSA-2168880
# 13   0.068800  0.063397             0         P07998
# 295  0.086667  0.041500             3   R-HSA-140877
# 130  0.087640  0.073422             1   R-HSA-977606
# 8    0.089600  0.034595             0         P01024
# 133  0.092135  0.039246             1  R-HSA-9694516
# 298  0.093333  0.040139             3   R-HSA-109581
